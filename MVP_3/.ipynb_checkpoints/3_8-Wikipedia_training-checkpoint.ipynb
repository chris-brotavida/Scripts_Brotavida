# %% [markdown]
# # Imports e inicialización del servidor

# %%
import mysql.connector
import os, getpass, re, requests
import gensim, nltk, unidecode
import wikipedia
import pandas as pd
import numpy as np
import spacy
import cvxpy as cp
import tensorflow as tf
from tqdm import tqdm
from mysql.connector import Error
from itertools import combinations
from ast import literal_eval
from collections import defaultdict
from scipy.spatial import distance
from bs4 import BeautifulSoup
from urllib.request import urlopen
K = 10

# %%
# Definición de parámetros de conexión
connection_params = {
    'host': 'localhost',
    'user': 'cmescobar',
    'database': 'foodb',
    'password': getpass.getpass(prompt='Introduzca la contraseña: ')
}

try:
    connection = mysql.connector.connect(**connection_params)

    if connection.is_connected():
        db_Info = connection.get_server_info()
        print("Connected to MySQL Server version ", db_Info)
        cursor = connection.cursor()

except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Introduzca la contraseña: ········
# Connected to MySQL Server version  8.0.26

# %% [markdown]
# # Obteniendo el dataframe de información

# %%
# Obteniendo la información del texto obtenido mediante wikipedia
df = pd.read_pickle('Summary/Food_wikitext.pkl')
df
# Out:
#       id                          name                 name_scientific  \
# 0      1                      Angelica                Angelica keiskei
# 1      2                 Savoy cabbage  Brassica oleracea var. sabauda
# 2      3                 Silver linden                  Tilia argentea
# 3      4                          Kiwi             Actinidia chinensis
# 4      5                        Allium                          Allium
# ..   ...                           ...                             ...
# 848  934                Asparagus fern              Asparagus setaceus
# 849  935          Thornless blackberry                Rubus ulmifolius
# 850  936  Tropical highland blackberry              Rubus adenotrichos
# 851  937             Andean blackberry                   Rubus glaucus
# 852  938                    Blackberry                           Rubus
#
#                                            description          wikipedia_id  \
# 0    Angelica is a genus of about 60 species of tal...              Angelica
# 1    Savoy cabbage (Brassica oleracea convar. capit...         Savoy cabbage
# 2    Tilia tomentosa (Silver Lime in the UK and Sil...       Tilia tomentosa
# 3    The kiwifruit, often shortened to kiwi in many...             Kiwifruit
# 4    Allium haematochiton is a species of wild onio...  Allium haematochiton
# ..                                                 ...                   ...
# 848  Asparagus setaceus, commonly called common asp...    Asparagus_setaceus
# 849  Rubus ulmifolius, commonly called thornless bl...      Rubus_ulmifolius
# 850  Rubus adenotrichos is commonly called tropical...    Rubus_adenotrichos
# 851  Rubus glaucus, commonly called Andean blackber...         Rubus_glaucus
# 852  The blackberry is an edible fruit produced by ...            Blackberry
#
#                                         wikipedia_text
# 0     About 50 species; see text Angelica is a genu...
# 1    Savoy cabbage (Brassica oleracea var. sabauda ...
# 2     Tilia tomentosa, known as silver linden in th...
# 3     Kiwifruit (commonly shortened to kiwi in Nort...
# 4     Allium haematochiton is a North American spec...
# ..                                                 ...
# 848   Asparagus setaceus, commonly known as common ...
# 849   Rubus ulmifolius is a species of wild blackbe...
# 850   Rubus adenotrichus Schltdl. Rubus adenotricho...
# 851   Rubus glaucus, commonly known as mora de Cast...
# 852   And hundreds more microspecies(the subgenus a...
#
# [853 rows x 6 columns]

# %% [markdown]
# # Preprocesando el texto

# %%
# Descargando las stopwords y el wordnet para el lemmatizer
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Chris-
# [nltk_data]     Brota\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Chris-
# [nltk_data]     Brota\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def preprocess_text_OLD(text, alphanumeric=True):
    # Tokenizar palabras ignorando la puntuación
    if alphanumeric:
        text = ' '.join(re.findall(r'\w+', text))
    else:
        text = ' '.join(re.findall(r'[A-Za-z]+', text))
    
    # Creando el lemmatizer y pasando a minúsculas
    lemmatizer = spacy.load('en_core_web_trf')
    tokens = lemmatizer(text)
    
    # Eliminando las stopwords
    keywords= [token.lemma_ for token in tokens 
               if token not in nltk.corpus.stopwords.words('english')]
    return keywords


def preprocess_text(text, alphanumeric=True):
    def _pos_tagger(nltk_tag):
        if nltk_tag.startswith('J'):
            return nltk.corpus.wordnet.ADJ
        elif nltk_tag.startswith('V'):
            return nltk.corpus.wordnet.VERB
        elif nltk_tag.startswith('N'):
            return nltk.corpus.wordnet.NOUN
        elif nltk_tag.startswith('R'):
            return nltk.corpus.wordnet.ADV
        else:         
            return None
    
    
    def _lemmatize(tokens):
        # Creando el lemmatizer y pasando a minúsculas
        lemmatizer = nltk.stem.WordNetLemmatizer()
        
        # Tokenizar la oración y encontrar el POS tag para cada token
        pos_tagged = nltk.pos_tag(tokens) 
        
        # Mapeando a los tags de interés y pasando a minúscula
        wordnet_tagged = list(map(lambda x: (x[0].lower(), _pos_tagger(x[1])), pos_tagged))
        
        # Definición de la oración lemmatimizada
        return [word if tag is None else lemmatizer.lemmatize(word, tag)
                for word, tag in wordnet_tagged]
    
    
    # Tokenizar palabras ignorando la puntuación
    if alphanumeric:
        tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')
    else:
        tokenizer = nltk.tokenize.RegexpTokenizer(r'[A-Za-z]+')
    tokens = tokenizer.tokenize(text)
    
    # Obtener los lemas
    lemmas = _lemmatize(tokens)

    # Eliminando las stopwords
    keywords = [lemma for lemma in lemmas if lemma not in nltk.corpus.stopwords.words('english')]
    
    return keywords


def get_data(dataframe):
    # Definición de la bag of words
    X_data = list()
    Y_data = list()
    
    # Definición de la lista de alimentos con errores
    error_list = list()
    
    # Para cada texto en la tabla
    for index, row in tqdm(dataframe.iterrows(), ncols=70, desc='Text'):
        # Obtener el texto
        text = row['wikipedia_text']
        # Preprocesando
        try:
            text = preprocess_text(text, alphanumeric=False)
            X_data.append(text)
            Y_data.append(row['name'])  
        except:
            print('No funciono:', text, index, row)
            error_list.append((index, row))
            
    return X_data, Y_data, error_list

# %% [markdown]
# # Definiendo los datos de entrada y salida

# %%
X_data, Y_data, error_list = get_data(df)
# Out:
# Text: 418it [02:08,  6.58it/s]
# No funciono: None 418 id                                                               444
# name                                                 French plantain
# name_scientific                                   Musa X paradisiaca
# description        Musa × paradisiaca is the accepted name for th...
# wikipedia_id                                      Musa × paradisiaca
# wikipedia_text                                                  None
# Name: 418, dtype: object
# Text: 616it [03:14,  4.77it/s]
# No funciono: None 616 id                                                               661
# name                                                          Dragée
# name_scientific                                                 None
# description        A dragée is a bite-sized, colorful form of con...
# wikipedia_id                                                  Dragée
# wikipedia_text                                                  None
# Name: 616, dtype: object
# Text: 628it [03:20,  1.95it/s]
# No funciono: None 628 id                                                               674
# name                                                            Pate
# name_scientific                                                 None
# description        Pâté is a mixture of ground meat and fat mince...
# wikipedia_id                                                    Pâté
# wikipedia_text                                                  None
# Name: 628, dtype: object
# Text: 740it [03:52,  7.33it/s]
# No funciono: None 738 id                                                               799
# name                                                         Cupuaçu
# name_scientific                               Theobroma grandiflorum
# description        Cupuaçu (also spelled Cupuassu, Cupuazú, and C...
# wikipedia_id                                                 Cupuaçu
# wikipedia_text                                                  None
# Name: 738, dtype: object
# Text: 849it [04:22,  6.32it/s]
# No funciono: None 845 id                                                               931
# name                                                       Yali pear
# name_scientific                               Pyrus × bretschneideri
# description        Yali pear, also called Chinese White Pear, is ...
# wikipedia_id                                  Pyrus_×_bretschneideri
# wikipedia_text                                                  None
# Name: 845, dtype: object
# Text: 853it [04:22,  3.25it/s]

# %%
np.savez('Summary/training_data.npz', X_data=X_data, Y_data=Y_data)

# %%
Y_labels = tf.keras.utils.to_categorical([i for i in range(len(Y_data))], 
                                          num_classes=None, dtype='int')

# %% [markdown]
# # Definición del bag of words

# %%
# Definición del set de todas las palabras que se encuentran
# en las descripciones
bag_of_words = set()

# Definición de la lista de largo de cada texto
len_texts = list()

for line in X_data:
    len_texts.append(len(line))
    for i in line:
        bag_of_words.add(i)

# %%
max(len_texts)
# Out:
# 6312

# %% [markdown]
# # Tokenizando

# %%
# Definición del token
tokenizer = tf.keras.preprocessing.text.Tokenizer()

# Ajustando el tokenizer a los textos
tokenizer.fit_on_texts(list(bag_of_words))

# Definiendo el tamaño del vocabulario
vocab_size = len(tokenizer.word_index) + 1

# Una vez definido el token para cada palabra, se transforman los textos mediante cada token
sequences = tokenizer.texts_to_sequences(X_data)

# Dado que las secuencias no tienen el mismo largo, se paddea para obtener una matriz
X_token = tf.keras.preprocessing.sequence.pad_sequences(sequences, maxlen=1000)
print(X_token.shape)
X_token
# Out:
# (848, 1000)
# array([[    0,     0,     0, ..., 19230,  8370, 30722],
#        [    0,     0,     0, ..., 13180, 25045, 23866],
#        [    0,     0,     0, ...,  3811, 10129,  8545],
#        ...,
#        [    0,     0,     0, ..., 14769, 25223, 28923],
#        [    0,     0,     0, ..., 26646, 38145,  4870],
#        [43262, 21403, 30931, ...,  2318,  8864, 19417]])

# %% [markdown]
# # Creación de los modelos

# %%
def model_1(vocab_size, out_dim, embedding_dim=100, embedding_trainable=True):
    # Capa de entrada
    x_in = tf.keras.layers.Input(shape=(None,))
    
    # Capa de embebido
    x = tf.keras.layers.Embedding(vocab_size, embedding_dim, 
                                  trainable=embedding_trainable)(x_in)
    
    # Red RNN + MLP
    x = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, dropout=0.5))(x)
    x = tf.keras.layers.Dense(32, activation='relu')(x)
    x = tf.keras.layers.Dense(64, activation='relu')(x)
    
    # Capa de salida
    x_out = tf.keras.layers.Dense(out_dim, activation='sigmoid')(x)
    
    # define the model
    model = tf.keras.Model(inputs=x_in, outputs=x_out)
    
    return model
    

def model_2(vocab_size, out_dim, embedding_dim=100, embedding_trainable=False):
    def _get_embedding_matrix():
        pass
    
    
    # Capa de entrada
    x_in = tf.keras.layers.Input(shape=(None,))
    
    # Capa de embebido
    x = tf.keras.layers.Embedding(vocab_size, embedding_dim, weights=[embedding_matrix], 
                                  trainable=embedding_trainable)(x_in)
    
    # Red RNN + MLP
    x = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, dropout=0.5))(x)
    x = tf.keras.layers.Dense(32, activation='relu')(x)
    x = tf.keras.layers.Dense(64, activation='relu')(x)
    
    # Capa de salida
    x_out = tf.keras.layers.Dense(out_dim, activation='sigmoid')(x)
    
    # define the model
    model = tf.keras.Model(inputs=x_in, outputs=x_out)
    
    return model

# %%
# Parámetros
embedding_dim = 100
embedding_trainable = True

model = model_1(vocab_size, out_dim=len(Y_data), embedding_dim=embedding_dim, 
                embedding_trainable=embedding_trainable)

# %%
# Compilando
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

#Implementing model checkpoins to save the best metric and do not lose it on training.
# checkpoint = tf.keras.callbacks.ModelCheckpoint("best_model1.hdf5", monitor='val_accuracy', 
#                                                 verbose=1, save_best_only=True, 
#                                                 mode='auto', period=1,save_weights_only=False)

# Implementando un EarlyStopping
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

# Entrenando
history = model.fit(X_token, Y_labels, epochs=100, callbacks=[early_stopping], batch_size=32)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 5s 173ms/step - loss: 0.0094 - accuracy: 0.0000e+00
# Epoch 2/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0092 - accuracy: 0.0012
# Epoch 3/100
# 27/27 [==============================] - 5s 167ms/step - loss: 0.0092 - accuracy: 0.0000e+00
# Epoch 4/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0092 - accuracy: 0.0012
# Epoch 5/100
# 27/27 [==============================] - 4s 167ms/step - loss: 0.0092 - accuracy: 0.0012
# Epoch 6/100
# 27/27 [==============================] - 4s 163ms/step - loss: 0.0092 - accuracy: 0.0000e+00
# Epoch 7/100
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0092 - accuracy: 0.0000e+00
# Epoch 8/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0092 - accuracy: 0.0000e+00
# Epoch 9/100
# 27/27 [==============================] - 5s 183ms/step - loss: 0.0092 - accuracy: 0.0000e+00
# Epoch 10/100
# 27/27 [==============================] - 5s 171ms/step - loss: 0.0092 - accuracy: 0.0024
# Epoch 11/100
# 27/27 [==============================] - 5s 170ms/step - loss: 0.0091 - accuracy: 0.0012
# Epoch 12/100
# 27/27 [==============================] - 4s 164ms/step - loss: 0.0091 - accuracy: 0.0024
# Epoch 13/100
# 27/27 [==============================] - 4s 164ms/step - loss: 0.0090 - accuracy: 0.0012
# Epoch 14/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0089 - accuracy: 0.0000e+00
# Epoch 15/100
# 27/27 [==============================] - 5s 172ms/step - loss: 0.0087 - accuracy: 0.0000e+00
# Epoch 16/100
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0086 - accuracy: 0.0012
# Epoch 17/100
# 27/27 [==============================] - 4s 167ms/step - loss: 0.0085 - accuracy: 0.0000e+00
# Epoch 18/100
# 27/27 [==============================] - 5s 171ms/step - loss: 0.0084 - accuracy: 0.0012TA: 1s - loss: 0.0
# Epoch 19/100
# 27/27 [==============================] - 5s 173ms/step - loss: 0.0083 - accuracy: 0.0059
# Epoch 20/100
# 27/27 [==============================] - 5s 169ms/step - loss: 0.0081 - accuracy: 0.0094
# Epoch 21/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0080 - accuracy: 0.0047
# Epoch 22/100
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0078 - accuracy: 0.0106
# Epoch 23/100
# 27/27 [==============================] - 4s 164ms/step - loss: 0.0076 - accuracy: 0.0094
# Epoch 24/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0075 - accuracy: 0.0177
# Epoch 25/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0073 - accuracy: 0.0142
# Epoch 26/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0072 - accuracy: 0.0189
# Epoch 27/100
# 27/27 [==============================] - 4s 164ms/step - loss: 0.0070 - accuracy: 0.02360s - loss: 0.0070 - ac
# Epoch 28/100
# 27/27 [==============================] - 5s 167ms/step - loss: 0.0069 - accuracy: 0.02831s - loss: 0.0068
# Epoch 29/100
# 27/27 [==============================] - 4s 164ms/step - loss: 0.0068 - accuracy: 0.03660s - loss: 0.0068 - accuracy: 0.
# Epoch 30/100
# 27/27 [==============================] - 4s 163ms/step - loss: 0.0066 - accuracy: 0.0224
# Epoch 31/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0065 - accuracy: 0.0389
# Epoch 32/100
# 27/27 [==============================] - 5s 175ms/step - loss: 0.0064 - accuracy: 0.0295
# Epoch 33/100
# 27/27 [==============================] - 4s 164ms/step - loss: 0.0063 - accuracy: 0.0366
# Epoch 34/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0062 - accuracy: 0.0413
# Epoch 35/100
# 27/27 [==============================] - 5s 169ms/step - loss: 0.0061 - accuracy: 0.0531
# Epoch 36/100
# 27/27 [==============================] - 5s 168ms/step - loss: 0.0060 - accuracy: 0.0413
# Epoch 37/100
# 27/27 [==============================] - 5s 174ms/step - loss: 0.0059 - accuracy: 0.0507
# Epoch 38/100
# 27/27 [==============================] - 5s 169ms/step - loss: 0.0058 - accuracy: 0.0554
# Epoch 39/100
# 27/27 [==============================] - 5s 176ms/step - loss: 0.0057 - accuracy: 0.06011s - loss: 0
# Epoch 40/100
# 27/27 [==============================] - 5s 170ms/step - loss: 0.0056 - accuracy: 0.0932
# Epoch 41/100
# 27/27 [==============================] - 5s 168ms/step - loss: 0.0055 - accuracy: 0.1026
# Epoch 42/100
# 27/27 [==============================] - 5s 169ms/step - loss: 0.0055 - accuracy: 0.0908
# Epoch 43/100
# 27/27 [==============================] - 5s 170ms/step - loss: 0.0054 - accuracy: 0.1002
# Epoch 44/100
# 27/27 [==============================] - 5s 170ms/step - loss: 0.0053 - accuracy: 0.1038
# Epoch 45/100
# 27/27 [==============================] - 5s 167ms/step - loss: 0.0052 - accuracy: 0.1050
# Epoch 46/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0052 - accuracy: 0.1179
# Epoch 47/100
# 27/27 [==============================] - 4s 167ms/step - loss: 0.0051 - accuracy: 0.1321
# Epoch 48/100
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0050 - accuracy: 0.1403
# Epoch 49/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0049 - accuracy: 0.1769
# Epoch 50/100
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0048 - accuracy: 0.1899
# Epoch 51/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0047 - accuracy: 0.2170
# Epoch 52/100
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0047 - accuracy: 0.1993
# Epoch 53/100
# 27/27 [==============================] - 5s 167ms/step - loss: 0.0046 - accuracy: 0.2311
# Epoch 54/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0045 - accuracy: 0.2370
# Epoch 55/100
# 27/27 [==============================] - 4s 167ms/step - loss: 0.0044 - accuracy: 0.2583
# Epoch 56/100
# 27/27 [==============================] - 5s 170ms/step - loss: 0.0044 - accuracy: 0.2524
# Epoch 57/100
# 27/27 [==============================] - 4s 164ms/step - loss: 0.0043 - accuracy: 0.2866
# Epoch 58/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0042 - accuracy: 0.3066
# Epoch 59/100
# 27/27 [==============================] - 4s 164ms/step - loss: 0.0041 - accuracy: 0.3160
# Epoch 60/100
# 27/27 [==============================] - 4s 164ms/step - loss: 0.0040 - accuracy: 0.3479
# Epoch 61/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0039 - accuracy: 0.3833
# Epoch 62/100
# 27/27 [==============================] - 5s 167ms/step - loss: 0.0038 - accuracy: 0.4151
# Epoch 63/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0037 - accuracy: 0.4139
# Epoch 64/100
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0036 - accuracy: 0.4292
# Epoch 65/100
# 27/27 [==============================] - 5s 168ms/step - loss: 0.0036 - accuracy: 0.4375
# Epoch 66/100
# 27/27 [==============================] - 5s 173ms/step - loss: 0.0035 - accuracy: 0.4505
# Epoch 67/100
# 27/27 [==============================] - 5s 170ms/step - loss: 0.0034 - accuracy: 0.5071
# Epoch 68/100
# 27/27 [==============================] - 5s 172ms/step - loss: 0.0033 - accuracy: 0.5118
# Epoch 69/100
# 27/27 [==============================] - 5s 171ms/step - loss: 0.0032 - accuracy: 0.5259
# Epoch 70/100
# 27/27 [==============================] - 5s 175ms/step - loss: 0.0031 - accuracy: 0.5531
# Epoch 71/100
# 27/27 [==============================] - 5s 202ms/step - loss: 0.0030 - accuracy: 0.5578
# Epoch 72/100
# 27/27 [==============================] - 5s 185ms/step - loss: 0.0030 - accuracy: 0.5719
# Epoch 73/100
# 27/27 [==============================] - 5s 168ms/step - loss: 0.0029 - accuracy: 0.5778
# Epoch 74/100
# 27/27 [==============================] - 5s 168ms/step - loss: 0.0028 - accuracy: 0.6038
# Epoch 75/100
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0027 - accuracy: 0.6085
# Epoch 76/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0026 - accuracy: 0.6450
# Epoch 77/100
# 27/27 [==============================] - 4s 163ms/step - loss: 0.0026 - accuracy: 0.6686
# Epoch 78/100
# 27/27 [==============================] - 4s 163ms/step - loss: 0.0025 - accuracy: 0.6981
# Epoch 79/100
# 27/27 [==============================] - 4s 162ms/step - loss: 0.0024 - accuracy: 0.6887
# Epoch 80/100
# 27/27 [==============================] - 5s 168ms/step - loss: 0.0023 - accuracy: 0.7429
# Epoch 81/100
# 27/27 [==============================] - 5s 169ms/step - loss: 0.0022 - accuracy: 0.7453
# Epoch 82/100
# 27/27 [==============================] - 5s 168ms/step - loss: 0.0022 - accuracy: 0.7406
# Epoch 83/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0022 - accuracy: 0.7535
# Epoch 84/100
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0021 - accuracy: 0.7535
# Epoch 85/100
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0020 - accuracy: 0.7594
# Epoch 86/100
# 27/27 [==============================] - 5s 168ms/step - loss: 0.0019 - accuracy: 0.8125
# Epoch 87/100
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0019 - accuracy: 0.8066
# Epoch 88/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0018 - accuracy: 0.8137
# Epoch 89/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0018 - accuracy: 0.8090
# Epoch 90/100
# 27/27 [==============================] - 5s 167ms/step - loss: 0.0017 - accuracy: 0.8184
# Epoch 91/100
# 27/27 [==============================] - 4s 164ms/step - loss: 0.0017 - accuracy: 0.8290
# Epoch 92/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0017 - accuracy: 0.8290
# Epoch 93/100
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0015 - accuracy: 0.8538
# Epoch 94/100
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0015 - accuracy: 0.8679
# Epoch 95/100
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0016 - accuracy: 0.8337
# Epoch 96/100
# 27/27 [==============================] - 5s 168ms/step - loss: 0.0015 - accuracy: 0.8656
# Epoch 97/100
# 27/27 [==============================] - 5s 168ms/step - loss: 0.0014 - accuracy: 0.8632
# Epoch 98/100
# 27/27 [==============================] - 5s 168ms/step - loss: 0.0013 - accuracy: 0.8785
# Epoch 99/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0013 - accuracy: 0.8785
# Epoch 100/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0013 - accuracy: 0.8762

# %% [markdown]
# # RNN prediction

# %%
text_to = ['citric'.split(' ')]
print(text_to)

# Una vez definido el token para cada palabra, se transforman los textos mediante cada token
text_to = tokenizer.texts_to_sequences(text_to)
print(text_to)

# # Dado que las secuencias no tienen el mismo largo, se paddea para obtener una matriz
# text_to = tf.keras.preprocessing.sequence.pad_sequences(text_to, maxlen=200)
# Out:
# [['citric']]
# [[37048]]

# %%
a = model.predict(text_to)
b = [(num, i) for num, i in enumerate(a[0])]
b.sort(key=lambda x: x[1], reverse=True)

for i in b:
    print(Y_data[i[0]])
# Out:
# Meatball
# Eggs
# Energy drink
# Nutritional drink
# Greenland halibut/turbot
# Ostrich
# Dried milk
# Lime
# Arctic blackberry
# Broad bean
# Whitefish
# King mackerel
# Lemon balm
# Curry powder
# Avocado
# Crisp bread
# Blackcurrant
# Ascidians
# Butterfat
# Naranjilla
# Black huckleberry
# Chinese chestnut
# Peppermint
# Soy bean
# Whisky
# Sweet bay
# Other candy
# Ucuhuba
# Carp bream
# Epazote
# Anise
# Trail mix
# Black salsify
# Roe
# Falafel
# Spirit
# Dock
# Chinese water chestnut
# Horseradish tree
# Wheat bread
# Rock ptarmigan
# Cumin
# Malabar plum
# Domestic pig
# Rape
# Chili
# Cracker
# Chinese cinnamon
# Sherry
# Common cabbage
# Pummelo
# Breadnut tree seed
# Chicken
# Napa cabbage
# Kohlrabi
# Jerusalem artichoke
# Tostada
# Semolina
# Other snack food
# Lingonberry
# Pink salmon
# Acorn
# Cherry tomato
# Atlantic pollock
# Colorado pinyon
# Wild leek
# Vinegar
# Purslane
# Savoy cabbage
# Mugwort
# White lupine
# Beefalo
# Pitanga
# Shark
# Romaine lettuce
# Cinnamon
# Columbidae (Dove, Pigeon)
# Common persimmon
# Coriander
# Borage
# Mountain hare
# Fruits
# Sweet marjoram
# Corn grits
# Bowhead whale
# Egg substitute
# Peanut
# Cocoa butter
# Lovage
# Rowanberry
# Bagel
# Atlantic mackerel
# Sheep (Mutton, Lamb)
# Black raspberry
# Striped bass
# Pie
# Spelt
# Miso
# Adzuki bean
# Pineapple
# Kai-lan
# Pecan nut
# Port wine
# Japanese chestnut
# Raisin bread
# Pita bread
# Spiny lobster
# Frybread
# Chinese cabbage
# Chinese broccoli
# Java plum
# Remoulade
# Baked beans
# Pastry
# Pacific cod
# Biscuit
# Cream
# Rice cake
# Frozen yogurt
# Lemon thyme
# Giant butterbur
# Chervil
# Rainbow smelt
# Angelica
# French toast
# Black elderberry
# Endive
# Lard
# Pacific rockfish
# Vodka
# Chayote
# Gelatin
# Bison
# Nopal
# Beer
# Couscous
# Radish
# Jute
# Soft drink
# Turnip
# Saskatoon berry
# Cherimoya
# Common buckwheat
# Sweet orange
# Loganberry
# Lingcod
# Quail
# Lima bean
# Scup
# Redcurrant
# Atlantic croaker
# Custard apple
# Welsh onion
# Yellowfin tuna
# Lemon grass
# Anchovy
# Sesbania flower
# Milkshake
# Garfish
# Mushrooms
# Pili nut
# Chocolate mousse
# Chum salmon
# Vegetarian food
# Vermouth
# Rambutan
# Winter savory
# Mammee apple
# Sweet custard
# Pepper (C. chinense)
# Grape
# Bean
# Emu
# Acerola
# Milkfish
# Tamale
# Scallop
# Other animal fat
# Sugar substitute
# Liquor
# Butternut squash
# Walleye
# Popcorn
# Orange roughy
# Cusk
# Ice cream cone
# Vaccinium (Blueberry, Cranberry, Huckleberry)
# Muscadine grape
# Common octopus
# Natal plum
# Atlantic halibut
# Grass pea
# Garden onion
# Cold cut
# Boysenberry
# Breakfast cereal
# Kiwi
# Common carp
# Asian pear
# Toffee
# Other fermented milk
# Egg roll
# Tortilla chip
# Bulgur
# Cloudberry
# Deerberry
# New Zealand spinach
# Pepper (Spice)
# Fruit salad
# Mamey sapote
# Globe artichoke
# Conch
# Shrimp
# Pupusa
# Common oregano
# Gefilte fish
# Rubus (Blackberry, Raspberry)
# Spot croaker
# Common chokecherry
# Ketchup
# Sauce
# Baked potato
# Ginkgo nuts
# Watercress
# Chinese mustard
# Alaska blackfish
# Narrowleaf cattail
# Marine mussel
# Pan dulce
# Small-leaf linden
# Spread
# Caraway
# Cake
# Perciformes
# Sablefish
# Coffee
# Pacific oyster
# Rainbow trout
# Lemon
# Snow crab
# Babassu palm
# Ringed seal
# American cranberry
# Crab
# Rapini
# Spinach
# White mustard
# Rabbiteye blueberry
# Albacore tuna
# Rum
# Coffee mocha
# Ravioli
# Phyllo dough
# Anatidae
# Annual wild rice
# Feijoa
# Pacific sardine
# Green vegetables
# Pumpkinseed sunfish
# Corn chip
# Cow milk, pasteurized, vitamin A + D added, 0% fat
# Mallard duck
# Eastern oyster
# Gelatin dessert
# Malabar spinach
# Wild celery
# Chickpea
# Wakame
# Haddock
# Sugar apple
# Brassicas
# Carrot
# Strawberry guava
# Grapefruit
# European anchovy
# Wax apple
# Oriental wheat
# Snapper
# Flatfish
# Squab
# Sorghum
# Akutaq
# Pollock
# Sturgeon
# Wild rice
# Pineappple sage
# Dandelion
# Wasabi
# Monkfish
# Japanese walnut
# Evergreen blackberry
# Atlantic salmon
# Passion fruit
# Capers
# Jackfruit
# Cow milk, pasteurized, vitamin D added, 3.25% fat
# Kombu
# Sapodilla
# Clawed lobster
# Sunflower
# European plum
# Red algae
# Jicama
# Papaya
# American shad
# Cocoa powder
# Breakfast sandwich
# Rocket salad
# Rocket salad (ssp.)
# American pokeweed
# Moth bean
# Casein
# Medlar
# Gadiformes
# Apricot
# Pepper (C. frutescens)
# Asparagus
# Buffalo currant
# Pomes
# Durian
# Cow milk, pasteurized, vitamin A + D added, 2% fat
# True sole
# Barley
# Tamarind
# Tea leaf willow
# Common ling
# Red bell pepper
# Canola
# Stuffing
# Arabica coffee
# Kale
# Celeriac
# Kefir
# Oat
# Cow milk, pasteurized, vitamin A + D added, 1% fat
# Cisco
# Atlantic wolffish
# Star fruit
# Leavening agent
# Pleuronectidae (Dab, Halibut, Plaice)
# Grape wine
# Taro
# Watermelon
# Nanking cherry
# Veggie burger
# Soy milk
# Fortified wine
# European cranberry
# Bitter gourd
# Junket
# Processed cheese
# Milk (Other mammals)
# Eggplant
# Atlantic menhaden
# Yellowtail amberjack
# Nougat
# Lumpsucker
# Common hazelnut
# Common grape
# Milk (Cow)
# Blue whiting
# Soup
# Japanese persimmon
# Milk (Human)
# Lowbush blueberry
# Bearded seal
# Ginger
# Hedge mustard
# Squid
# Cashew nut
# Morchella (Morel)
# Oyster mushroom
# Stew
# Juniperus communis
# Molasses
# Parsnip
# Spotted seal
# Pot marjoram
# Almond
# Shiitake
# Arrowhead
# Rowal
# Amaranth
# Garden tomato
# Tortilla
# Freshwater drum
# Walrus
# Sea cucumber
# Garden rhubarb
# Crustaceans
# Pomegranate
# Evaporated milk
# Hibiscus tea
# Yam
# Rice
# Ymer
# Skipjack tuna
# Black-eyed pea
# Mollusks
# Prairie turnip
# Persian lime
# Tofu
# Black crowberry
# Vegetable juice
# Sourdough
# Waffle
# Marshmallow
# Yellow bell pepper
# Arepa
# Chanterelle
# Snail
# Gin
# Other bread
# Okra
# Dolphin fish
# Dripping
# Red beetroot
# Butternut
# Macadamia nut (M. tetraphylla)
# Beverages
# Pacific herring
# Nachos
# Green bell pepper
# Striped mullet
# Orange bell pepper
# Asparagus racemosus
# Sago palm
# Horned melon
# Yellow wax bean
# Cichlidae (Tilapia)
# Broccoli
# Bog bilberry
# Mango
# Salmonidae (Salmon, Trout)
# Potato bread
# Ocean pout
# Hamburger
# Other alcoholic beverage
# Atlantic herring
# Common beet
# Horchata
# Hot chocolate
# Cloves
# Triticale
# Nutmeg
# Sacred lotus
# Enokitake
# Margarine
# Dumpling
# Focaccia
# Lambsquarters
# Honey
# Pepper
# Tree fern
# Marzipan
# Turkey
# Coffee substitute
# Ostrich fern
# Hushpuppy
# Mexican groundcherry
# Percoidei (Bass and others)
# Winter squash
# Pear
# Lemon sole
# Pulses
# Fig
# Abalone
# Star anise
# Brussel sprouts
# Robusta coffee
# Rosemary
# Quince
# Tea
# Roman camomile
# Alaska pollock
# Milk and milk products
# Sour cherry
# Alcoholic beverages
# Pacific salmon
# Chimichanga
# Atlantic cod
# White cabbage
# Evening primrose
# Bivalvia (Clam, Mussel, Oyster)
# Pacific halibut
# Norway lobster
# Cauliflower
# Gadus (Common cod)
# Tunicate
# Maitake
# Burbot
# Chocolate spread
# Guava
# Mandarin orange (Clementine, Tangerine)
# Thistle
# Quesadilla
# Macaroni and cheese
# Beech nut
# Burrito
# Turbot
# Cloud ear fungus
# Common wheat
# Orange mint
# Chestnut
# Brazil nut
# Nuts
# Climbing bean
# Norway haddock
# Channel catfish
# Fenugreek
# Tartary buckwheat
# True seal
# Elk
# Empanada
# Blackberry
# Domestic goat
# Lasagna
# Chinese bayberry
# Bayberry
# Meatloaf
# Rye
# Candy bar
# Pigeon pea
# Groundcherry
# Malus (Crab apple)
# Green bean
# Common bean
# Kelp
# Sheepshead
# Sausage
# Cetacea (Dolphin, Porpoise, Whale)
# Vanilla
# Common verbena
# Sorrel
# Freshwater eel
# Safflower
# Cornmint
# Kumquat
# Jellyfish
# Wild carrot
# Syrup
# Lentils
# Horse
# Enchilada
# Fruit gum
# Florida pompano
# Potato
# Scombridae (Bonito, Mackerel, Tuna)
# Butter
# Pasta
# Gentiana lutea
# Peach
# Cabbage
# Sourdock
# Mustard
# Crayfish
# Thunnus
# Whey
# Wheat
# Andean blackberry
# Chives
# Highbush blueberry
# Summer grape
# Red king crab
# Italian sweet red pepper
# European chestnut
# Fats and oils
# Garden cress
# Tallow
# Pheasant
# Fudge
# Northern pike
# Sockeye salmon
# Dill
# Garlic
# Daikon radish
# Date
# Calabash
# Pot pie
# Heart of palm
# Blue mussel
# Common salsify
# Spanish mackerel
# Fennel
# Sweet basil
# Winged bean
# Scarlet bean
# Opium poppy
# Allspice
# Alpine sweetvetch
# Potato chip
# Elliott's blueberry
# Fruit preserve
# Shea tree
# Common dab
# Pie crust
# Hot dog
# Common pea
# Red huckleberry
# Tarragon
# Soft-necked garlic
# Coho salmon
# Elderberry
# Saffron
# Shallot
# Abiyuch
# Norway pout
# Pancake
# Sesame
# Dulce de leche
# Hazelnut
# Buffalo
# Fishes
# Succotash
# Potato gratin
# European rabbit
# American butterfish
# Nectarine
# Taco
# Dough
# Green zucchini
# Gram bean
# Zwieback
# Tinda
# Relish
# Black walnut
# Bilberry
# Hummus
# Apple
# Beluga whale
# Squashberry
# Grouper
# Deer
# Icing
# Velvet duck
# Tilefish
# Cocktail
# Chocolate
# True oyster
# Mule deer
# Sheefish
# Purple mangosteen
# Mundu
# Lake trout
# Red raspberry
# Apple cider
# Rice bread
# Cocoa bean
# Walnut
# Hyssop
# Lemon verbena
# Japanese pumpkin
# Quinoa
# Soy yogurt
# Ginseng
# Ice cream
# Fruit juice
# Swordfish
# Rye bread
# Pepper (C. baccatum)
# Sake
# Other fish product
# Clupeinae (Herring, Sardine, Sprat)
# Pikeperch
# Cottonseed
# Mentha
# Soursop
# Ohelo berry
# Castanospermum australe
# Catjang pea
# Muskmelon
# Meringue
# Wild boar
# Sunburst squash (pattypan squash)
# Sugar
# Garland chrysanthemum
# Mexican oregano
# Macadamia nut
# Cucurbita
# Cheese
# Teff
# Broad whitefish
# Persimmon
# True frog
# Purple laver
# Blue crab
# Black chokeberry
# Flour
# Milk substitute
# Coalfish pollock
# Corn
# Cucumber
# Fish burger
# Yautia
# Smelt
# Skunk currant
# Rose hip
# Common thyme
# Oregon yampah
# Yardlong bean
# Roselle
# Other frozen dessert
# Cocoa liquor
# Carob
# Anguilliformes
# Celery leaves
# Pistachio
# Other sandwich
# Celery stalks
# Jostaberry
# Spearmint
# Hippoglossus (Common halibut)
# Lichee
# White sucker
# Sparkleberry
# German camomile
# Pudding
# Steller sea lion
# Pectin
# Pacific ocean perch
# Pine nut
# Sweet potato
# Yellow pond-lily
# Mustard spinach
# Silver linden
# Rabbit
# Gooseberry
# Mulberry
# Summer savory
# Thornless blackberry
# Chinook salmon
# Pizza
# Komatsuna
# Poppy
# Tropical highland blackberry
# Salmonberry
# Greylag goose
# Jujube
# Cascade huckleberry
# Whiting
# Asparagus fern
# Corn salad
# Olive
# Oil-seed Camellia
# Root vegetables
# Buttermilk
# Leek
# Painted comber
# Bluefish
# Fireweed
# Shortening
# Agar
# Alaska blueberry
# Cuttlefish
# Cooking oil
# Sweet cherry
# Chewing gum
# Millet
# Evergreen huckleberry
# Salad
# Irish moss
# Tapioca pearl
# Alfalfa
# Cowpea
# Hard wheat
# Fox grape
# Pepper (Capsicum)
# Common walnut
# Allium
# Dungeness crab
# Hyacinth bean
# Common mushroom
# Albizia gummifera
# Prickly pear
# Condensed milk
# Cornbread
# Nuttall cockle
# Loquat
# Liquorice
# Chicory
# Flaxseed
# Chicory roots
# Soy sauce
# Citrus
# Lotus
# Parsley
# Guinea hen
# Horseradish
# Chia
# Lupine
# Oval-leaf huckleberry
# Scrapple
# Pacific jack mackerel
# Salt
# Mountain yam
# Pak choy
# Leather chiton
# Water
# Greenthread tea
# Mung bean
# Whelk
# Baby food
# Coconut
# Charr
# Red rice
# Adobo
# Swamp cabbage
# Madeira wine
# Banana
# Cattle (Beef, Veal)
# North Pacific giant octopus
# Plains prickly pear
# Mixed nuts
# Salad dressing
# Nance
# Canada blueberry
# Black mulberry
# Cassava
# Agave
# Breadfruit
# Northern bluefin tuna
# Towel gourd
# Catfish
# Pepper (C. pubescens)
# Common sage
# Chinese chives
# Turmeric
# Prunus (Cherry, Plum)
# Arrowroot
# Swiss chard
# Piki bread
# Lettuce
# Wax gourd
# Sea-buckthornberry
# Swede
# Green turtle
# Spiny dogfish
# Bamboo shoots
# Natto
# Strawberry
# Hickory nut
# American lobster
# Cardamom
# Burdock
# Ceylon cinnamon
# Cardoon
# Longan
# Jew's ear
