# %% [markdown]
# # Imports e inicialización del servidor

# %%
import mysql.connector
import os, getpass, re, requests
import gensim, nltk, unidecode
import wikipedia
import pandas as pd
import numpy as np
import spacy
import cvxpy as cp
import tensorflow as tf
from tqdm import tqdm
from mysql.connector import Error
from itertools import combinations
from ast import literal_eval
from collections import defaultdict
from scipy.spatial import distance
from bs4 import BeautifulSoup
from urllib.request import urlopen
K = 10

# %%
# Definición de parámetros de conexión
connection_params = {
    'host': 'localhost',
    'user': 'cmescobar',
    'database': 'foodb',
    'password': getpass.getpass(prompt='Introduzca la contraseña: ')
}

try:
    connection = mysql.connector.connect(**connection_params)

    if connection.is_connected():
        db_Info = connection.get_server_info()
        print("Connected to MySQL Server version ", db_Info)
        cursor = connection.cursor()

except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Introduzca la contraseña: ········
# Connected to MySQL Server version  8.0.26

# %% [markdown]
# # Obteniendo el dataframe de información

# %%
# Obteniendo la información del texto obtenido mediante wikipedia
df = pd.read_pickle('Summary/Food_wikitext.pkl')
df
# Out:
#       id                          name                 name_scientific  \
# 0      1                      Angelica                Angelica keiskei
# 1      2                 Savoy cabbage  Brassica oleracea var. sabauda
# 2      3                 Silver linden                  Tilia argentea
# 3      4                          Kiwi             Actinidia chinensis
# 4      5                        Allium                          Allium
# ..   ...                           ...                             ...
# 848  934                Asparagus fern              Asparagus setaceus
# 849  935          Thornless blackberry                Rubus ulmifolius
# 850  936  Tropical highland blackberry              Rubus adenotrichos
# 851  937             Andean blackberry                   Rubus glaucus
# 852  938                    Blackberry                           Rubus
#
#                                            description          wikipedia_id  \
# 0    Angelica is a genus of about 60 species of tal...              Angelica
# 1    Savoy cabbage (Brassica oleracea convar. capit...         Savoy cabbage
# 2    Tilia tomentosa (Silver Lime in the UK and Sil...       Tilia tomentosa
# 3    The kiwifruit, often shortened to kiwi in many...             Kiwifruit
# 4    Allium haematochiton is a species of wild onio...  Allium haematochiton
# ..                                                 ...                   ...
# 848  Asparagus setaceus, commonly called common asp...    Asparagus_setaceus
# 849  Rubus ulmifolius, commonly called thornless bl...      Rubus_ulmifolius
# 850  Rubus adenotrichos is commonly called tropical...    Rubus_adenotrichos
# 851  Rubus glaucus, commonly called Andean blackber...         Rubus_glaucus
# 852  The blackberry is an edible fruit produced by ...            Blackberry
#
#                                         wikipedia_text
# 0     About 50 species; see text Angelica is a genu...
# 1    Savoy cabbage (Brassica oleracea var. sabauda ...
# 2     Tilia tomentosa, known as silver linden in th...
# 3     Kiwifruit (commonly shortened to kiwi in Nort...
# 4     Allium haematochiton is a North American spec...
# ..                                                 ...
# 848   Asparagus setaceus, commonly known as common ...
# 849   Rubus ulmifolius is a species of wild blackbe...
# 850   Rubus adenotrichus Schltdl. Rubus adenotricho...
# 851   Rubus glaucus, commonly known as mora de Cast...
# 852   And hundreds more microspecies(the subgenus a...
#
# [853 rows x 6 columns]

# %% [markdown]
# # Preprocesando el texto

# %%
# Descargando las stopwords y el wordnet para el lemmatizer
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Chris-
# [nltk_data]     Brota\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Chris-
# [nltk_data]     Brota\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def preprocess_text_OLD(text, alphanumeric=True):
    # Tokenizar palabras ignorando la puntuación
    if alphanumeric:
        text = ' '.join(re.findall(r'\w+', text))
    else:
        text = ' '.join(re.findall(r'[A-Za-z]+', text))
    
    # Creando el lemmatizer y pasando a minúsculas
    lemmatizer = spacy.load('en_core_web_trf')
    tokens = lemmatizer(text)
    
    # Eliminando las stopwords
    keywords= [token.lemma_ for token in tokens 
               if token not in nltk.corpus.stopwords.words('english')]
    return keywords


def preprocess_text(text, alphanumeric=True):
    def _pos_tagger(nltk_tag):
        if nltk_tag.startswith('J'):
            return nltk.corpus.wordnet.ADJ
        elif nltk_tag.startswith('V'):
            return nltk.corpus.wordnet.VERB
        elif nltk_tag.startswith('N'):
            return nltk.corpus.wordnet.NOUN
        elif nltk_tag.startswith('R'):
            return nltk.corpus.wordnet.ADV
        else:         
            return None
    
    
    def _lemmatize(tokens):
        # Creando el lemmatizer y pasando a minúsculas
        lemmatizer = nltk.stem.WordNetLemmatizer()
        
        # Tokenizar la oración y encontrar el POS tag para cada token
        pos_tagged = nltk.pos_tag(tokens) 
        
        # Mapeando a los tags de interés y pasando a minúscula
        wordnet_tagged = list(map(lambda x: (x[0].lower(), _pos_tagger(x[1])), pos_tagged))
        
        # Definición de la oración lemmatimizada
        return [word if tag is None else lemmatizer.lemmatize(word, tag)
                for word, tag in wordnet_tagged]
    
    
    # Tokenizar palabras ignorando la puntuación
    if alphanumeric:
        tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')
    else:
        tokenizer = nltk.tokenize.RegexpTokenizer(r'[A-Za-z]+')
    tokens = tokenizer.tokenize(text)
    
    # Obtener los lemas
    lemmas = _lemmatize(tokens)

    # Eliminando las stopwords
    keywords = [lemma for lemma in lemmas if lemma not in nltk.corpus.stopwords.words('english')]
    
    return keywords


def get_data(dataframe):
    # Definición de la bag of words
    X_data = list()
    Y_data = list()
    
    # Definición de la lista de alimentos con errores
    error_list = list()
    
    # Para cada texto en la tabla
    for index, row in tqdm(dataframe.iterrows(), ncols=70, desc='Text'):
        # Obtener el texto
        text = row['wikipedia_text']
        # Preprocesando
        try:
            text = preprocess_text(text, alphanumeric=False)
            X_data.append(text)
            Y_data.append(row['name'])  
        except:
            print('No funciono:', text, index, row)
            error_list.append((index, row))
            
    return X_data, Y_data, error_list

# %% [markdown]
# # Definiendo los datos de entrada y salida

# %%
X_data, Y_data, error_list = get_data(df)
# Out:
# Text: 64it [00:20,  2.93it/s]
# No funciono:  Saffron (pronounced /ˈsæfrən/ or /ˈsæfrɒn/) is a spice derived from the flower of Crocus sativus, commonly known as the "saffron crocus". The vivid crimson stigma and styles, called threads, are collected and dried for use mainly as a seasoning and colouring agent in food. Saffron has long been the world's costliest spice by weight. Although some doubts remain on its origin, it is believed that saffron originated in Iran. However, Greece and Mesopotamia have also been suggested as the possible region of origin of this plant. Harold McGee states that it was domesticated in or near Greece during the Bronze Age. C. sativus is possibly a triploid form of Crocus cartwrightianus, which is also known as "wild saffron". Saffron crocus slowly propagated throughout much of Eurasia and was later brought to parts of North Africa, North America, and Oceania. Saffron's taste and iodoform-like or hay-like fragrance result from the phytochemicals picrocrocin and safranal. It also contains a carotenoid pigment, crocin, which imparts a rich golden-yellow hue to dishes and textiles. Its recorded history is attested in a 7th-century BC Assyrian botanical treatise, and has been traded and used for thousands of years. In the 21st century, Iran produces some 90% of the world total for saffron with best quality. At US$5,000 per kg or higher, saffron is the world's most expensive spice. A degree of uncertainty surrounds the origin of the English word "saffron". It might stem from the 12th-century Old French term safran, which comes from the Latin word safranum, from the Arabic za'farān, which comes from the Persian word zarparan meaning "gold strung" (implying either the golden stamens of the flower or the golden color it creates when used as flavor). The domesticated saffron crocus, Crocus sativus, is an autumn-flowering perennial plant unknown in the wild. It probably descends from the eastern Mediterranean autumn-flowering Crocus cartwrightianus which is also known as "wild saffron" and originated in Crete or Central Asia. C. thomasii and C. pallasii are other possible sources. As a genetically monomorphic clone, it slowly propagated throughout much of Eurasia. It is a sterile triploid form, which means that three homologous sets of chromosomes make up each specimen's genetic complement; C. sativus bears eight chromosomal bodies per set, making for 24 in total. Being sterile, the purple flowers of C. sativus fail to produce viable seeds; reproduction hinges on human assistance: clusters of corms, underground, bulb-like, starch-storing organs, must be dug up, divided, and replanted. A corm survives for one season, producing via vegetative division up to ten "cormlets" that can grow into new plants in the next season. The compact corms are small, brown globules that can measure as large as 5 cm (2 in) in diameter, have a flat base, and are shrouded in a dense mat of parallel fibres; this coat is referred to as the "corm tunic". Corms also bear vertical fibres, thin and net-like, that grow up to 5 cm (2 in) above the plant's neck. The plant sprouts 5–11 white and non-photosynthetic leaves known as cataphylls. These membrane-like structures cover and protect 5 to 11 true leaves as they bud and develop on the crocus flower. The latter are thin, straight, and blade-like green foliage leaves, which are 1–3 mm (1⁄32–1⁄8 in), in diameter, which either expand after the flowers have opened ("hysteranthous") or do so simultaneously with their blooming ("synanthous"). C. sativus cataphylls are suspected by some to manifest prior to blooming when the plant is irrigated relatively early in the growing season. Its floral axes, or flower-bearing structures, bear bracteoles, or specialised leaves, that sprout from the flower stems; the latter are known as pedicels. After aestivating in spring, the plant sends up its true leaves, each up to 40 cm (16 in) in length. Only in October, after most other flowering plants have released their seeds, do its bril ...
# name                                                         Saffron
# name_scientific                                       Crocus sativus
# description        Saffron is a spice derived from the flower of ...
# wikipedia_id                                                 Saffron
# wikipedia_text      Saffron (pronounced /ˈsæfrən/ or /ˈsæfrɒn/) i...
# Name: 62, dtype: object
# Text: 256it [01:21,  2.37it/s]Exception ignored in: <function SeekableUnicodeStreamReader.__del__ at 0x000001456D4FF430>
# Traceback (most recent call last):
#   File "c:\users\chris-brota\appdata\local\programs\python\python38\lib\site-packages\nltk\data.py", line 1160, in __del__
#     self.close()
#   File "c:\users\chris-brota\appdata\local\programs\python\python38\lib\site-packages\nltk\data.py", line 1195, in close
#     self.stream.close()
# KeyboardInterrupt:
# Text: 269it [01:25,  4.18it/s]
# No funciono:  The red king crab (Paralithodes camtschaticus), also called Kamchatka crab or Alaskan king crab, is a species of king crab native to the far northern Pacific Ocean, including the Bering Sea and Gulf of Alaska, but also introduced to the Barents Sea. It grows to a leg span of 1.8 m (5.9 ft), and is heavily targeted by fisheries. The red king crab is the largest species of king crab. Red king crabs can reach a carapace width up to 28 cm (11 in), a leg span of 1.8 m (5.9 ft), and a weight of 12.7 kg (28 lb). Males grow larger than females. Today, red king crabs infrequently surpass 17 cm (7 in) in carapace width and the average male landed in the Bering Sea weighs 2.9 kg (6.4 lb). It was named after the color it turns when it is cooked rather than the color of a living animal, which tends to be more burgundy. The red king crab is native to the Bering Sea, North Pacific Ocean, around the Kamchatka Peninsula and neighboring Alaskan waters. It was introduced artificially by the Soviet Union into the Murmansk Fjord, Barents Sea, during the 1960s to provide a new, and valuable, catch in Europe. Red king crabs have been seen in water temperatures that range from −1.8 to 12.8 °C (28.8–55.0 °F), with typical being 3.2 to 5.5 °C (37.8–41.9 °F). Immatures prefer temperatures below 6 °C (43 °F). The depth at which it can live has much to do with what stage of its lifecycle it is in; newly hatched crab (zoea larvae) stay in the shallower waters where food and protection are plentiful. Usually, after the age of two, the crabs move down to depths of 20–50 m (66–164 ft) and take part in what is known as podding; hundreds of crabs come together in tight, highly concentrated groups. Adult crabs are found usually more than 200 m down on the sand and muddy areas in the substrate. They migrate in the winter or early spring to shallower depths for mating, but most of their lives are spent in the deep waters where they feed. It is the most coveted of the commercially sold king crab species, and it is the most expensive per unit weight. It is most commonly caught in the Bering Sea and Norton Sound, Alaska, and is particularly difficult to catch, but is nonetheless one of the most preferred crabs for consumption. Red king crabs are experiencing a steady decline in numbers in their native far east coastal waters for unclear reasons, though several theories for the precipitous drop in the crab population have been proposed, including overfishing, warmer waters, and increased fish predation. Fishing controls set by the United States in the 1980s and 2000s have failed to stem the decline. In the 1960s, the Soviet Union transported red king crabs from the North Pacific Ocean to the Murmansk Fjord. They did not survive transport overland, so a batch was flown in, which survived, was released, and bred and spread in the wild. It was first found in Norway in 1977. In the Barents Sea, it is an invasive species and its population is increasing tremendously. This is causing great concern to local environmentalists and local fishermen, as the crab eats everything it comes across and is spreading very rapidly, eating most seabed life and "creating a desert". Since its introduction in the 1960s, it has spread west along the Norwegian coast and also has reached Svalbard. The species keeps on advancing southwards along the coast of Norway and some scientists think they are advancing around 50 km (31 mi) a year. In Norway they are sometimes called "Stalin's crabs". By the mid 1990s, the king crabs reached North Cape. The Norwegian Institute of Marine Research found in 2010–2013 that they have reached Sørøya and are breeding there. A few have been caught as far south as Tromsø. There is fear of the result if they reach the cod breeding grounds off Lofoten. A report on 8 June 2009 said that a red king crab had been caught off Skogsvåg at Sotra south of Bergen in south Norway. An important natural predator, the giant Pacific octopus (Enteroctopus dofleini, fo ...
# name                                                   Red king crab
# name_scientific                           Paralithodes camtschaticus
# description        The red king crab, Paralithodes camtschaticus,...
# wikipedia_id                              Paralithodes camtschaticus
# wikipedia_text      The red king crab (Paralithodes camtschaticus...
# Name: 268, dtype: object
# Text: 282it [01:28,  4.04it/s]

# %%
np.savez('Summary/training_data.npz', X_data=X_data, Y_data=Y_data)

# %% [markdown]
# # Cargar datos

# %%
data = np.load('Summary/training_data.npz', allow_pickle=True)
X_data = data['X_data']
Y_data = data['Y_data']

# %%
Y_labels = tf.keras.utils.to_categorical([i for i in range(len(Y_data))], 
                                          num_classes=None, dtype='int')

# %% [markdown]
# # Definición del bag of words

# %%
# Definición del set de todas las palabras que se encuentran
# en las descripciones
bag_of_words = set()

# Definición de la lista de largo de cada texto
len_texts = list()

for line in X_data:
    len_texts.append(len(line))
    for i in line:
        bag_of_words.add(i)

# %%
max(len_texts)
# Out:
# 6312

# %% [markdown]
# # Tokenizando

# %%
# Definición del token
tokenizer = tf.keras.preprocessing.text.Tokenizer()

# Ajustando el tokenizer a los textos
tokenizer.fit_on_texts(list(bag_of_words))

# Definiendo el tamaño del vocabulario
vocab_size = len(tokenizer.word_index) + 1

# Una vez definido el token para cada palabra, se transforman los textos mediante cada token
sequences = tokenizer.texts_to_sequences(X_data)

# Dado que las secuencias no tienen el mismo largo, se paddea para obtener una matriz
X_token = tf.keras.preprocessing.sequence.pad_sequences(sequences, maxlen=1000)
print(X_token.shape)
X_token
# Out:
# (853, 1000)
# array([[    0,     0,     0, ..., 35412, 15019,  3961],
#        [    0,     0,     0, ..., 46872, 37500, 12713],
#        [    0,     0,     0, ...,  6768, 19797,  5683],
#        ...,
#        [    0,     0,     0, ..., 42356, 17040, 17187],
#        [    0,     0,     0, ..., 15991, 45824, 18269],
#        [19102,  2740, 10184, ..., 21242, 15204, 32287]])

# %% [markdown]
# # Creación de los modelos

# %%
def model_1(vocab_size, out_dim, embedding_dim=100, embedding_trainable=True):
    # Capa de entrada
    x_in = tf.keras.layers.Input(shape=(None,))
    
    # Capa de embebido
    x = tf.keras.layers.Embedding(vocab_size, embedding_dim, 
                                  trainable=embedding_trainable)(x_in)
    
    # Red RNN + MLP
    x = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, dropout=0.5))(x)
    x = tf.keras.layers.Dense(32, activation='relu')(x)
    x = tf.keras.layers.Dense(64, activation='relu')(x)
    
    # Capa de salida
    x_out = tf.keras.layers.Dense(out_dim, activation='sigmoid')(x)
    
    # define the model
    model = tf.keras.Model(inputs=x_in, outputs=x_out)
    
    return model
    

def model_2(vocab_size, out_dim, embedding_dim=100, embedding_trainable=False):
    def _get_embedding_matrix():
        pass
    
    
    # Capa de entrada
    x_in = tf.keras.layers.Input(shape=(None,))
    
    # Capa de embebido
    x = tf.keras.layers.Embedding(vocab_size, embedding_dim, weights=[embedding_matrix], 
                                  trainable=embedding_trainable)(x_in)
    
    # Red RNN + MLP
    x = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, dropout=0.5))(x)
    x = tf.keras.layers.Dense(32, activation='relu')(x)
    x = tf.keras.layers.Dense(64, activation='relu')(x)
    
    # Capa de salida
    x_out = tf.keras.layers.Dense(out_dim, activation='sigmoid')(x)
    
    # define the model
    model = tf.keras.Model(inputs=x_in, outputs=x_out)
    
    return model

# %%
# Parámetros
embedding_dim = 100
embedding_trainable = True

model = model_1(vocab_size, out_dim=len(Y_data), embedding_dim=embedding_dim, 
                embedding_trainable=embedding_trainable)

# %%
# Compilando
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

#Implementing model checkpoins to save the best metric and do not lose it on training.
# checkpoint = tf.keras.callbacks.ModelCheckpoint("best_model1.hdf5", monitor='val_accuracy', 
#                                                 verbose=1, save_best_only=True, 
#                                                 mode='auto', period=1,save_weights_only=False)

# Implementando un EarlyStopping
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

# Entrenando
history = model.fit(X_token, Y_labels, epochs=100, callbacks=[early_stopping], batch_size=32)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0103 - accuracy: 0.0000e+00
# Epoch 2/100
# 27/27 [==============================] - 5s 167ms/step - loss: 0.0095 - accuracy: 0.0000e+00
# Epoch 3/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0094 - accuracy: 0.0000e+00
# Epoch 4/100
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0094 - accuracy: 0.0000e+00
# Epoch 5/100
# 27/27 [==============================] - 4s 166ms/step - loss: 0.0094 - accuracy: 0.0012
# Epoch 6/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0094 - accuracy: 0.0012
# Epoch 7/100
# 27/27 [==============================] - 4s 167ms/step - loss: 0.0094 - accuracy: 0.0000e+00
# Epoch 8/100
# 27/27 [==============================] - 5s 167ms/step - loss: 0.0094 - accuracy: 0.0000e+00
# Epoch 9/100
# 27/27 [==============================] - 4s 165ms/step - loss: 0.0094 - accuracy: 0.0000e+003s - loss: 0.009 - ETA: 1s - loss: 0.0092
# Epoch 10/100
# 27/27 [==============================] - 5s 171ms/step - loss: 0.0094 - accuracy: 0.0000e+00

# %% [markdown]
# # RNN prediction

# %%
text_to = ['citric fruit'.split(' ')]
print(text_to)

# Una vez definido el token para cada palabra, se transforman los textos mediante cada token
text_to = tokenizer.texts_to_sequences(text_to)
print(text_to)

# # Dado que las secuencias no tienen el mismo largo, se paddea para obtener una matriz
# text_to = tf.keras.preprocessing.sequence.pad_sequences(text_to, maxlen=200)
# Out:
# [['citric', 'fruit']]
# [[5205, 25999]]

# %%
a = model.predict(text_to)
b = [(num, i) for num, i in enumerate(a[0])]
b.sort(key=lambda x: x[1], reverse=True)

for i in b:
    print(Y_data[i[0]], round(i[1] * 100, 2), '%')
# Out:
# Butternut squash 44.53 %
# Pili nut 44.25 %
# Atlantic menhaden 44.24 %
# Sherry 44.23 %
# Common hazelnut 44.19 %
# Common dab 44.19 %
# Safflower 44.17 %
# Soft-necked garlic 44.17 %
# Rainbow smelt 44.16 %
# Pepper (C. chinense) 44.15 %
# Black mulberry 44.15 %
# Winter squash 44.15 %
# Rabbit 44.14 %
# Chinese water chestnut 44.14 %
# Breadfruit 44.13 %
# Swede 44.13 %
# Sourdough 44.13 %
# Deerberry 44.13 %
# Domestic pig 44.13 %
# Bivalvia (Clam, Mussel, Oyster) 44.13 %
# Cloudberry 44.12 %
# Port wine 44.12 %
# Chives 44.12 %
# Hippoglossus (Common halibut) 44.11 %
# Candy bar 44.11 %
# Velvet duck 44.1 %
# Lettuce 44.1 %
# Mandarin orange (Clementine, Tangerine) 44.1 %
# Avocado 44.09 %
# Turnip 44.08 %
# Mulberry 44.08 %
# Sake 44.08 %
# Pistachio 44.08 %
# European rabbit 44.08 %
# Celeriac 44.08 %
# Vanilla 44.08 %
# Jicama 44.08 %
# Baked beans 44.08 %
# Dripping 44.08 %
# Soy sauce 44.08 %
# Turkey 44.07 %
# Whelk 44.07 %
# Date 44.06 %
# Orange bell pepper 44.06 %
# Evaporated milk 44.06 %
# Sweet bay 44.06 %
# Miso 44.06 %
# Red bell pepper 44.06 %
# Pacific sardine 44.05 %
# Rowal 44.05 %
# Alcoholic beverages 44.05 %
# Green zucchini 44.05 %
# Tapioca pearl 44.05 %
# Remoulade 44.05 %
# Gin 44.04 %
# Pacific oyster 44.04 %
# Pacific cod 44.04 %
# Meatloaf 44.04 %
# Chocolate spread 44.03 %
# Sweet basil 44.03 %
# Bitter gourd 44.03 %
# Nutritional drink 44.03 %
# Macaroni and cheese 44.03 %
# Corn 44.03 %
# Gooseberry 44.02 %
# Muscadine grape 44.02 %
# Mixed nuts 44.02 %
# Dragée 44.02 %
# Pollock 44.02 %
# Cocoa bean 44.02 %
# Cetacea (Dolphin, Porpoise, Whale) 44.02 %
# Hyssop 44.02 %
# Flour 44.02 %
# Cherimoya 44.02 %
# Shrimp 44.02 %
# Toffee 44.02 %
# Salad dressing 44.02 %
# Millet 44.02 %
# Domestic goat 44.01 %
# Brazil nut 44.01 %
# Vermouth 44.01 %
# Milkfish 44.0 %
# Quince 44.0 %
# Cow milk, pasteurized, vitamin D added, 3.25% fat 44.0 %
# Kiwi 44.0 %
# Salmonidae (Salmon, Trout) 44.0 %
# Alaska blueberry 44.0 %
# Fruit preserve 44.0 %
# Black walnut 44.0 %
# Lemon verbena 43.99 %
# Pepper (Spice) 43.99 %
# Green bean 43.99 %
# Hot dog 43.99 %
# Ringed seal 43.98 %
# Deer 43.98 %
# Beer 43.98 %
# Cucumber 43.98 %
# Butter 43.98 %
# Lentils 43.97 %
# Albizia gummifera 43.97 %
# Abalone 43.97 %
# Leather chiton 43.97 %
# Coconut 43.97 %
# Alfalfa 43.97 %
# Chocolate mousse 43.97 %
# Nuttall cockle 43.97 %
# Wax gourd 43.97 %
# Orange roughy 43.97 %
# Yam 43.96 %
# Cheese 43.96 %
# Dumpling 43.96 %
# Celery stalks 43.96 %
# Burdock 43.96 %
# Summer savory 43.96 %
# Cocoa powder 43.96 %
# Sunflower 43.96 %
# Sparkleberry 43.96 %
# Red king crab 43.96 %
# Wasabi 43.95 %
# Norway haddock 43.95 %
# Monkfish 43.95 %
# Japanese pumpkin 43.95 %
# Crab 43.95 %
# Chickpea 43.95 %
# Pitanga 43.95 %
# Sourdock 43.95 %
# Common cabbage 43.95 %
# Natto 43.94 %
# Pikeperch 43.94 %
# Heart of palm 43.94 %
# Crustaceans 43.94 %
# French toast 43.94 %
# Turbot 43.94 %
# Rosemary 43.93 %
# Cattle (Beef, Veal) 43.93 %
# Biscuit 43.93 %
# Tortilla 43.93 %
# New Zealand spinach 43.93 %
# Tarragon 43.93 %
# Common persimmon 43.93 %
# Cashew nut 43.93 %
# Grass pea 43.93 %
# Vinegar 43.93 %
# Eastern oyster 43.92 %
# Buffalo 43.92 %
# Broad bean 43.92 %
# Sapodilla 43.92 %
# Napa cabbage 43.92 %
# Loquat 43.92 %
# Macadamia nut 43.92 %
# Breadnut tree seed 43.92 %
# Oyster mushroom 43.92 %
# Atlantic wolffish 43.92 %
# Wild boar 43.91 %
# Soursop 43.91 %
# Gadiformes 43.91 %
# Tamarind 43.91 %
# American butterfish 43.91 %
# Vegetarian food 43.91 %
# Sweet marjoram 43.91 %
# Crayfish 43.91 %
# Cow milk, pasteurized, vitamin A + D added, 0% fat 43.91 %
# Cracker 43.91 %
# Vaccinium (Blueberry, Cranberry, Huckleberry) 43.91 %
# Lambsquarters 43.91 %
# Komatsuna 43.91 %
# Lemon 43.9 %
# Ceylon cinnamon 43.9 %
# Allium 43.9 %
# Curry powder 43.9 %
# Salmonberry 43.9 %
# Lingonberry 43.9 %
# Pineapple 43.9 %
# Morchella (Morel) 43.9 %
# Rice 43.9 %
# Cisco 43.9 %
# Molasses 43.9 %
# Mollusks 43.9 %
# Grapefruit 43.9 %
# Charr 43.9 %
# Kumquat 43.9 %
# Apple 43.9 %
# Persimmon 43.9 %
# Empanada 43.9 %
# Daikon radish 43.9 %
# Pecan nut 43.89 %
# Sugar 43.89 %
# Fig 43.89 %
# Sacred lotus 43.89 %
# Sorrel 43.89 %
# Common oregano 43.89 %
# Baby food 43.89 %
# Striped mullet 43.88 %
# Black huckleberry 43.88 %
# Pate 43.88 %
# Cichlidae (Tilapia) 43.88 %
# Cowpea 43.88 %
# Burrito 43.88 %
# Hickory nut 43.88 %
# Nectarine 43.88 %
# Anatidae 43.88 %
# Lime 43.88 %
# Cardoon 43.88 %
# Garland chrysanthemum 43.88 %
# Tofu 43.88 %
# Kohlrabi 43.88 %
# Pummelo 43.88 %
# Ginseng 43.88 %
# Arctic blackberry 43.87 %
# Amaranth 43.87 %
# Mallard duck 43.87 %
# Ucuhuba 43.87 %
# Rice bread 43.87 %
# Wax apple 43.87 %
# Annual wild rice 43.87 %
# Carob 43.87 %
# Persian lime 43.86 %
# Norway pout 43.86 %
# Northern pike 43.86 %
# Ginger 43.86 %
# Common grape 43.86 %
# Cocoa butter 43.86 %
# Dolphin fish 43.86 %
# Grape wine 43.86 %
# Broad whitefish 43.86 %
# Wild leek 43.85 %
# Redcurrant 43.85 %
# Channel catfish 43.85 %
# Spread 43.85 %
# Quesadilla 43.85 %
# Ketchup 43.85 %
# Chinese chestnut 43.85 %
# Arrowhead 43.85 %
# Arepa 43.85 %
# Dill 43.85 %
# Lupine 43.85 %
# Pacific rockfish 43.85 %
# Arrowroot 43.85 %
# Milk (Human) 43.84 %
# Black salsify 43.84 %
# True seal 43.84 %
# Chervil 43.84 %
# Couscous 43.84 %
# Shiitake 43.84 %
# Common salsify 43.84 %
# Shallot 43.84 %
# Cream 43.84 %
# Dough 43.84 %
# Common mushroom 43.84 %
# Wakame 43.84 %
# Conch 43.84 %
# Cornmint 43.84 %
# Tallow 43.84 %
# Skipjack tuna 43.83 %
# Other sandwich 43.83 %
# Florida pompano 43.83 %
# Chayote 43.83 %
# Japanese chestnut 43.83 %
# Vegetable juice 43.83 %
# Soup 43.83 %
# Kombu 43.83 %
# Honey 43.83 %
# Pulses 43.83 %
# Towel gourd 43.83 %
# Mustard spinach 43.83 %
# Tortilla chip 43.83 %
# Soy milk 43.83 %
# Dock 43.83 %
# Longan 43.83 %
# Capers 43.83 %
# Medlar 43.83 %
# Leavening agent 43.83 %
# Wheat bread 43.83 %
# Rocket salad 43.83 %
# Gelatin dessert 43.83 %
# Walnut 43.83 %
# Abiyuch 43.83 %
# Yautia 43.83 %
# Cornbread 43.83 %
# Japanese persimmon 43.83 %
# Pear 43.82 %
# Trail mix 43.82 %
# Garlic 43.82 %
# Anchovy 43.82 %
# Lard 43.82 %
# Semolina 43.82 %
# Lima bean 43.82 %
# Epazote 43.82 %
# North Pacific giant octopus 43.82 %
# Purslane 43.82 %
# Pizza 43.82 %
# Blue crab 43.82 %
# Opium poppy 43.82 %
# Oriental wheat 43.82 %
# Pita bread 43.82 %
# Atlantic halibut 43.81 %
# Asparagus fern 43.81 %
# Chicory roots 43.81 %
# Cloves 43.81 %
# Lemon thyme 43.81 %
# Purple laver 43.81 %
# Fish burger 43.81 %
# Atlantic pollock 43.81 %
# Asparagus 43.81 %
# Icing 43.81 %
# Rice cake 43.81 %
# Mundu 43.81 %
# Potato bread 43.81 %
# Snow crab 43.81 %
# Bearded seal 43.81 %
# Lumpsucker 43.81 %
# Black chokeberry 43.81 %
# Mushrooms 43.8 %
# Japanese walnut 43.8 %
# Evergreen blackberry 43.8 %
# Cabbage 43.8 %
# Squab 43.8 %
# Anise 43.8 %
# Nougat 43.8 %
# Roselle 43.8 %
# Natal plum 43.8 %
# Cottonseed 43.79 %
# Sweet potato 43.79 %
# Spanish mackerel 43.79 %
# Tilefish 43.79 %
# Breakfast sandwich 43.79 %
# Cow milk, pasteurized, vitamin A + D added, 2% fat 43.79 %
# Grape 43.79 %
# Red raspberry 43.79 %
# Acorn 43.79 %
# Atlantic croaker 43.79 %
# Alaska blackfish 43.79 %
# Hummus 43.78 %
# Beluga whale 43.78 %
# Butterfat 43.78 %
# Saffron 43.78 %
# Nachos 43.78 %
# Hazelnut 43.78 %
# Wild carrot 43.78 %
# Yellow wax bean 43.78 %
# Papaya 43.78 %
# Whey 43.78 %
# Fenugreek 43.78 %
# Greenland halibut/turbot 43.78 %
# Parsley 43.78 %
# Yellowtail amberjack 43.78 %
# Red algae 43.78 %
# Chinese chives 43.78 %
# American shad 43.78 %
# Percoidei (Bass and others) 43.78 %
# Catjang pea 43.78 %
# Tinda 43.77 %
# Northern bluefin tuna 43.77 %
# Kale 43.77 %
# Common walnut 43.77 %
# Caraway 43.77 %
# Lingcod 43.77 %
# Jujube 43.77 %
# Common ling 43.77 %
# Chimichanga 43.77 %
# Enokitake 43.77 %
# Pacific ocean perch 43.77 %
# Junket 43.77 %
# Marzipan 43.77 %
# Norway lobster 43.77 %
# Watermelon 43.77 %
# Roman camomile 43.77 %
# Mugwort 43.77 %
# Ginkgo nuts 43.77 %
# Common beet 43.77 %
# Sugar apple 43.76 %
# Blackberry 43.76 %
# Squid 43.76 %
# Salt 43.76 %
# Rocket salad (ssp.) 43.76 %
# Guinea hen 43.76 %
# Fats and oils 43.76 %
# Greylag goose 43.76 %
# Mexican groundcherry 43.76 %
# Atlantic salmon 43.76 %
# Pineappple sage 43.76 %
# Bluefish 43.76 %
# Corn salad 43.76 %
# Meringue 43.76 %
# Star anise 43.76 %
# Soy yogurt 43.75 %
# White mustard 43.75 %
# Scup 43.75 %
# Whitefish 43.75 %
# Sockeye salmon 43.75 %
# Fortified wine 43.75 %
# Swordfish 43.75 %
# Baked potato 43.75 %
# Tunicate 43.75 %
# Peach 43.75 %
# Common verbena 43.75 %
# Emu 43.75 %
# Jute 43.75 %
# Savoy cabbage 43.75 %
# Ohelo berry 43.75 %
# Scrapple 43.75 %
# Watercress 43.75 %
# Colorado pinyon 43.75 %
# Pacific herring 43.75 %
# Pacific jack mackerel 43.75 %
# Cascade huckleberry 43.75 %
# Calabash 43.75 %
# Water 43.75 %
# Piki bread 43.74 %
# Bamboo shoots 43.74 %
# Lemon balm 43.74 %
# Enchilada 43.74 %
# Sesbania flower 43.74 %
# Star fruit 43.74 %
# Pacific halibut 43.74 %
# Winged bean 43.74 %
# Cucurbita 43.74 %
# Lovage 43.74 %
# Pleuronectidae (Dab, Halibut, Plaice) 43.74 %
# Pepper 43.74 %
# Phyllo dough 43.74 %
# Globe artichoke 43.74 %
# Fruit salad 43.74 %
# Elliott's blueberry 43.74 %
# Pot pie 43.74 %
# Waffle 43.74 %
# Rose hip 43.74 %
# Taco 43.74 %
# Common carp 43.74 %
# Lasagna 43.74 %
# Shark 43.73 %
# Flaxseed 43.73 %
# Egg substitute 43.73 %
# Okra 43.73 %
# Common octopus 43.73 %
# Gram bean 43.73 %
# Bagel 43.73 %
# Giant butterbur 43.73 %
# Tree fern 43.73 %
# Prickly pear 43.73 %
# Allspice 43.73 %
# Clawed lobster 43.73 %
# Marine mussel 43.73 %
# Pepper (Capsicum) 43.73 %
# Egg roll 43.73 %
# Black elderberry 43.73 %
# Rye 43.72 %
# Gadus (Common cod) 43.72 %
# Oregon yampah 43.72 %
# Nanking cherry 43.72 %
# Cocktail 43.72 %
# Pepper (C. pubescens) 43.72 %
# True oyster 43.72 %
# Soft drink 43.72 %
# Mentha 43.72 %
# Thistle 43.72 %
# Strawberry guava 43.72 %
# Anguilliformes 43.72 %
# Pupusa 43.72 %
# Rowanberry 43.72 %
# Prunus (Cherry, Plum) 43.72 %
# Lowbush blueberry 43.72 %
# Winter savory 43.72 %
# Fireweed 43.71 %
# Brassicas 43.71 %
# Java plum 43.71 %
# Ice cream cone 43.71 %
# Eggplant 43.71 %
# Red huckleberry 43.71 %
# Albacore tuna 43.71 %
# Butternut 43.71 %
# Mammee apple 43.71 %
# Horned melon 43.71 %
# American cranberry 43.71 %
# Other animal fat 43.7 %
# Relish 43.7 %
# Nance 43.7 %
# Ymer 43.7 %
# Red beetroot 43.7 %
# Hard wheat 43.7 %
# Scombridae (Bonito, Mackerel, Tuna) 43.7 %
# Vodka 43.7 %
# Buttermilk 43.7 %
# Pink salmon 43.7 %
# Sour cherry 43.7 %
# Banana 43.7 %
# Dungeness crab 43.7 %
# Apricot 43.69 %
# Plains prickly pear 43.69 %
# Milkshake 43.69 %
# Agar 43.69 %
# Atlantic herring 43.69 %
# Jostaberry 43.69 %
# Striped bass 43.69 %
# Summer grape 43.69 %
# Spinach 43.69 %
# Wild celery 43.69 %
# Gelatin 43.68 %
# Highbush blueberry 43.68 %
# Silver linden 43.68 %
# Spotted seal 43.68 %
# Horseradish tree 43.68 %
# Apple cider 43.68 %
# Steller sea lion 43.68 %
# Milk (Cow) 43.68 %
# Moth bean 43.68 %
# Olive 43.68 %
# Malus (Crab apple) 43.68 %
# Lichee 43.68 %
# Custard apple 43.67 %
# Salad 43.67 %
# Black-eyed pea 43.67 %
# Shea tree 43.67 %
# Rainbow trout 43.67 %
# Peppermint 43.67 %
# Adobo 43.67 %
# European plum 43.67 %
# Spearmint 43.67 %
# Blackcurrant 43.67 %
# Ocean pout 43.67 %
# Mung bean 43.67 %
# Sesame 43.67 %
# Liquor 43.67 %
# Bayberry 43.67 %
# Snail 43.67 %
# Walleye 43.67 %
# Sweet custard 43.66 %
# Hyacinth bean 43.66 %
# True frog 43.66 %
# Spiny dogfish 43.66 %
# Grouper 43.66 %
# Chili 43.66 %
# Other candy 43.66 %
# Tostada 43.66 %
# Haddock 43.66 %
# Rock ptarmigan 43.66 %
# Fudge 43.66 %
# Lotus 43.66 %
# Pancake 43.66 %
# Naranjilla 43.66 %
# Spiny lobster 43.66 %
# Pan dulce 43.66 %
# Pie crust 43.66 %
# Condensed milk 43.66 %
# Green vegetables 43.66 %
# Sugar substitute 43.65 %
# Green bell pepper 43.65 %
# Pomegranate 43.65 %
# German camomile 43.65 %
# Cherry tomato 43.65 %
# Flatfish 43.65 %
# Coffee substitute 43.65 %
# Walrus 43.65 %
# Alaska pollock 43.65 %
# Fruit juice 43.65 %
# Pepper (C. baccatum) 43.64 %
# Thunnus 43.64 %
# Burbot 43.64 %
# Horchata 43.64 %
# Pheasant 43.64 %
# Asparagus racemosus 43.64 %
# Pumpkinseed sunfish 43.64 %
# Sheepshead 43.64 %
# Scallop 43.64 %
# Tea leaf willow 43.64 %
# Yellowfin tuna 43.64 %
# Wheat 43.64 %
# Jew's ear 43.63 %
# Cumin 43.63 %
# Fruits 43.63 %
# Tartary buckwheat 43.63 %
# Other fish product 43.63 %
# Prairie turnip 43.63 %
# Cinnamon 43.63 %
# Madeira wine 43.63 %
# Sorghum 43.63 %
# Horseradish 43.63 %
# Bean 43.63 %
# Elderberry 43.63 %
# Evening primrose 43.63 %
# Almond 43.63 %
# Malabar plum 43.63 %
# Purple mangosteen 43.63 %
# Peanut 43.63 %
# Eggs 43.63 %
# Quinoa 43.63 %
# Chinese cabbage 43.62 %
# Crisp bread 43.62 %
# Clupeinae (Herring, Sardine, Sprat) 43.62 %
# Leek 43.62 %
# Beech nut 43.62 %
# Passion fruit 43.62 %
# Elk 43.62 %
# Pigeon pea 43.62 %
# Greenthread tea 43.62 %
# Liquorice 43.62 %
# Mule deer 43.62 %
# Chestnut 43.62 %
# Zwieback 43.62 %
# Margarine 43.61 %
# Freshwater eel 43.61 %
# Saskatoon berry 43.61 %
# Potato gratin 43.61 %
# Chicory 43.61 %
# Bowhead whale 43.61 %
# Cupuaçu 43.61 %
# Chanterelle 43.61 %
# Dried milk 43.61 %
# White cabbage 43.61 %
# Common bean 43.61 %
# Gefilte fish 43.6 %
# Jerusalem artichoke 43.6 %
# Chia 43.6 %
# Gentiana lutea 43.6 %
# Loganberry 43.6 %
# Pomes 43.6 %
# Common buckwheat 43.6 %
# Taro 43.6 %
# Swiss chard 43.6 %
# Carp bream 43.59 %
# Scarlet bean 43.59 %
# Cow milk, pasteurized, vitamin A + D added, 1% fat 43.59 %
# Italian sweet red pepper 43.59 %
# Sea cucumber 43.59 %
# Fishes 43.59 %
# Frybread 43.59 %
# Columbidae (Dove, Pigeon) 43.59 %
# Triticale 43.59 %
# Acerola 43.59 %
# Quail 43.58 %
# Sausage 43.58 %
# Cake 43.58 %
# Corn chip 43.58 %
# Teff 43.58 %
# Malabar spinach 43.58 %
# Rum 43.58 %
# Canada blueberry 43.58 %
# Potato chip 43.57 %
# Pasta 43.57 %
# Garden onion 43.57 %
# Feijoa 43.57 %
# Root vegetables 43.57 %
# Guava 43.57 %
# Common chokecherry 43.57 %
# Broccoli 43.57 %
# Stuffing 43.57 %
# Chewing gum 43.57 %
# Roe 43.57 %
# Chinese mustard 43.56 %
# Frozen yogurt 43.56 %
# Atlantic mackerel 43.56 %
# Cuttlefish 43.56 %
# Pectin 43.56 %
# Sweet cherry 43.56 %
# Celery leaves 43.56 %
# Freshwater drum 43.56 %
# Succotash 43.56 %
# Stew 43.56 %
# Atlantic cod 43.55 %
# Corn grits 43.55 %
# Asian pear 43.55 %
# Falafel 43.55 %
# Durian 43.55 %
# Energy drink 43.55 %
# Rapini 43.55 %
# Bulgur 43.55 %
# Borage 43.55 %
# Chocolate 43.55 %
# Oil-seed Camellia 43.54 %
# Turmeric 43.54 %
# Sturgeon 43.54 %
# Breakfast cereal 43.54 %
# Common thyme 43.54 %
# Jackfruit 43.54 %
# Ascidians 43.54 %
# Sheep (Mutton, Lamb) 43.54 %
# Pie 43.54 %
# Ice cream 43.54 %
# Pastry 43.54 %
# Chinese cinnamon 43.53 %
# Nutmeg 43.53 %
# Garden cress 43.53 %
# Ravioli 43.53 %
# Common pea 43.53 %
# Poppy 43.53 %
# Milk and milk products 43.53 %
# Garden tomato 43.53 %
# Angelica 43.53 %
# Marshmallow 43.53 %
# Strawberry 43.52 %
# Garden rhubarb 43.52 %
# Spelt 43.52 %
# Other alcoholic beverage 43.52 %
# Other snack food 43.52 %
# Mustard 43.52 %
# Kelp 43.52 %
# European chestnut 43.51 %
# Yellow bell pepper 43.51 %
# Beverages 43.51 %
# Squashberry 43.51 %
# Sago palm 43.51 %
# Veggie burger 43.5 %
# Cocoa liquor 43.5 %
# European cranberry 43.5 %
# Coffee mocha 43.5 %
# Welsh onion 43.5 %
# Romaine lettuce 43.5 %
# Brussel sprouts 43.5 %
# Cauliflower 43.5 %
# Raisin bread 43.5 %
# Cusk 43.5 %
# Lake trout 43.5 %
# Yellow pond-lily 43.5 %
# Black crowberry 43.49 %
# Arabica coffee 43.49 %
# Sablefish 43.49 %
# Other frozen dessert 43.49 %
# Swamp cabbage 43.49 %
# Buffalo currant 43.48 %
# Chinook salmon 43.48 %
# French plantain 43.47 %
# Sheefish 43.47 %
# Kai-lan 43.47 %
# Painted comber 43.47 %
# Shortening 43.47 %
# Carrot 43.47 %
# King mackerel 43.47 %
# Akutaq 43.47 %
# Processed cheese 43.47 %
# Tamale 43.47 %
# Spirit 43.46 %
# Hamburger 43.46 %
# Bog bilberry 43.46 %
# Milk (Other mammals) 43.46 %
# Endive 43.46 %
# Green turtle 43.46 %
# Mamey sapote 43.46 %
# Jellyfish 43.46 %
# Radish 43.46 %
# Cardamom 43.46 %
# Pak choy 43.46 %
# Ostrich fern 43.45 %
# Andean blackberry 43.45 %
# Barley 43.45 %
# Alpine sweetvetch 43.45 %
# Common sage 43.45 %
# Pepper (C. frutescens) 43.45 %
# Coriander 43.45 %
# Whiting 43.45 %
# Juniperus communis 43.45 %
# Other fermented milk 43.45 %
# Hushpuppy 43.45 %
# Bilberry 43.45 %
# White sucker 43.45 %
# Coffee 43.45 %
# Chinese bayberry 43.45 %
# Mountain yam 43.44 %
# Kefir 43.44 %
# Cold cut 43.44 %
# Muskmelon 43.44 %
# Popcorn 43.43 %
# Blue mussel 43.43 %
# Castanospermum australe 43.43 %
# Sauce 43.43 %
# Dandelion 43.42 %
# Ostrich 43.42 %
# Rye bread 43.42 %
# Canola 43.42 %
# Babassu palm 43.41 %
# Lemon sole 43.41 %
# Citrus 43.41 %
# Chinese broccoli 43.41 %
# Other bread 43.4 %
# Focaccia 43.4 %
# Rape 43.4 %
# Mountain hare 43.4 %
# Snapper 43.39 %
# Evergreen huckleberry 43.39 %
# Bison 43.39 %
# Fruit gum 43.39 %
# Lemon grass 43.39 %
# American lobster 43.39 %
# Climbing bean 43.39 %
# Horse 43.39 %
# Orange mint 43.38 %
# Small-leaf linden 43.38 %
# White lupine 43.38 %
# Rambutan 43.38 %
# Skunk currant 43.38 %
# Smelt 43.37 %
# European anchovy 43.37 %
# Cloud ear fungus 43.37 %
# Chum salmon 43.37 %
# True sole 43.37 %
# Cassava 43.37 %
# Pot marjoram 43.37 %
# Tropical highland blackberry 43.36 %
# Coalfish pollock 43.36 %
# Blue whiting 43.36 %
# Sea-buckthornberry 43.36 %
# Fox grape 43.36 %
# Black raspberry 43.35 %
# Rubus (Blackberry, Raspberry) 43.35 %
# Mango 43.34 %
# Robusta coffee 43.34 %
# Adzuki bean 43.34 %
# Irish moss 43.34 %
# Syrup 43.34 %
# Agave 43.34 %
# Hot chocolate 43.33 %
# Nopal 43.33 %
# Fennel 43.33 %
# Sunburst squash (pattypan squash) 43.32 %
# Garfish 43.32 %
# Sweet orange 43.31 %
# Thornless blackberry 43.31 %
# Oat 43.31 %
# Maitake 43.3 %
# Pudding 43.3 %
# Pacific salmon 43.29 %
# Rabbiteye blueberry 43.28 %
# Dulce de leche 43.28 %
# Casein 43.28 %
# Pine nut 43.28 %
# Tea 43.28 %
# Hibiscus tea 43.28 %
# Coho salmon 43.28 %
# Meatball 43.27 %
# Yali pear 43.27 %
# American pokeweed 43.26 %
# Chicken 43.26 %
# Whisky 43.24 %
# Wild rice 43.23 %
# Red rice 43.22 %
# Macadamia nut (M. tetraphylla) 43.21 %
# Oval-leaf huckleberry 43.21 %
# Mexican oregano 43.21 %
# Perciformes 43.18 %
# Yardlong bean 43.18 %
# Cooking oil 43.17 %
# Groundcherry 43.17 %
# Narrowleaf cattail 43.17 %
# Spot croaker 43.14 %
# Potato 43.11 %
# Parsnip 43.1 %
# Hedge mustard 43.09 %
# Beefalo 43.09 %
# Nuts 43.04 %
# Catfish 43.04 %
# Milk substitute 43.03 %
# Soy bean 42.98 %
# Common wheat 42.98 %
# Boysenberry 42.95 %
