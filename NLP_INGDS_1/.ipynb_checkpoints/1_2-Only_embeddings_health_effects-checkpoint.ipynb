# %% [markdown]
# # Imports e inicialización del servidor

# %%
import mysql.connector
import os, getpass, re, requests
import gensim
import pandas as pd
import numpy as np
import cvxpy as cp
import tensorflow as tf
import matplotlib.pyplot as plt
from mysql.connector import Error
from itertools import combinations
from ast import literal_eval
from collections import defaultdict
from scipy.spatial import distance
from sklearn.manifold import TSNE
from bs4 import BeautifulSoup
import plotly.graph_objects as go
K = 10

# %%
# Definición de parámetros de conexión
connection_params = {
    'host': 'localhost',
    'user': 'cmescobar',
    'database': 'foodb',
    'password': getpass.getpass(prompt='Introduzca la contraseña: ')
}

try:
    connection = mysql.connector.connect(**connection_params)

    if connection.is_connected():
        db_Info = connection.get_server_info()
        print("Connected to MySQL Server version ", db_Info)
        cursor = connection.cursor()

except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Introduzca la contraseña: ········
# Connected to MySQL Server version  8.0.26

# %%
def cosine_similarity(A, b):
    # Definición de los argumentos de la similaridad coseno
    A_dot_b = np.sum(A * b, axis=1)
    A_norm = np.sqrt(np.sum(A ** 2, axis=1))
    b_norm = np.sqrt(np.sum(b ** 2))
    return A_dot_b / (A_norm * b_norm)


def find_Nprox_words(terms_to_rev, N_words, metric='euclidean'):
    # Definición del diccionario de palabras
    word_dict_out = dict()

    for term in terms_to_rev:
        # Definición del vector de embedding
        embed_term = embeddings_index.get(term)

        if embed_term is None: continue
        
        if metric == 'euclidean':
            # Diferencia cuadrática
            dif_metric = np.sum((embedding_matrix - embed_term) ** 2, axis=1)
            reverse_sort = False
        
        elif metric == 'cosine':
            # Similaridad coseno
            dif_metric = (cosine_similarity(embedding_matrix, embed_term) + 1) / 2
            reverse_sort = True
        
        # Etiquetando posición
        pos_dif = [(i, delta) for i, delta in enumerate(dif_metric)]

        # Ordenando
        pos_dif.sort(key=lambda x: x[1], reverse=reverse_sort)

        # Agregar al diccionario
        word_dict_out[term] = [(embedding_words[i[0]], i[0], i[1]) for i in pos_dif[1:1+N_words]]

    return word_dict_out


def find_Nprox_words_joint(terms_to_rev, N_words, metric='euclidean'):
    # Definición del diccionario de palabras
    word_dict_out = dict()
    
    # Definición de un vector de embedding total
    embed_total = list()
    
    for term in terms_to_rev:
        # Definición del vector de embedding
        embed_term = embeddings_index.get(term)

        if embed_term is None: continue
        else: embed_total.append(embed_term)    
        
    # Calculando la media del vector embebido
    embed_total = np.array(embed_total).mean(axis=0)
    
    if metric == 'euclidean':
        # Diferencia cuadrática
        dif_metric = np.sum((embedding_matrix - embed_total) ** 2, axis=1)
        reverse_sort = False

    elif metric == 'cosine':
        # Similaridad coseno
        dif_metric = (cosine_similarity(embedding_matrix, embed_total) + 1) / 2
        reverse_sort = True

    # Etiquetando posición
    pos_dif = [(i, delta) for i, delta in enumerate(dif_metric)]

    # Ordenando
    pos_dif.sort(key=lambda x: x[1], reverse=reverse_sort)

    # Agregar al diccionario
    word_dict_out[' '.join(terms_to_rev)] = [(embedding_words[i[0]], i[0], i[1]) for i in pos_dif[1:1+N_words]]

    return word_dict_out

# %% [markdown]
# # Obteniendo los datos

# %%
query = \
'''SELECT he.id, he.name, he.description, he.chebi_name, he.chebi_id, he.chebi_definition 
   FROM health_effects he 
'''

# Solicitud de la query
df = pd.read_sql(query, connection)
df
# Out:
#         id                                           name  \
# 0        1                                  (+)-inotropic
# 1        2                               (-)-chronotropic
# 2        3                                  (-)-inotropic
# 3        4  11beta-hydroxysteroid-dehydrogenase inhibitor
# 4        5                      12-lipoxygenase inhibitor
# ...    ...                                            ...
# 1430  1431                     xanthine oxidase inhibitor
# 1431  1432                                      inhibitor
# 1432  1433                       prostaglandin antagonist
# 1433  1434                 platelet aggregation inhibitor
# 1434  1435    EC 3.2.1.18 (exo-alpha-sialidase) inhibitor
#
#                                             description  \
# 0     An agent that alters the force or energy of mu...
# 1     An agent that may change the heart rate by aff...
# 2     An agent that alters the force or energy of mu...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 1430                                               None
# 1431                                               None
# 1432                                               None
# 1433                                               None
# 1434                                               None
#
#                                        chebi_name chebi_id  \
# 0                                            None     None
# 1                                            None     None
# 2                                            None     None
# 3                                enzyme inhibitor    23924
# 4                                enzyme inhibitor    23924
# ...                                           ...      ...
# 1430                   xanthine oxidase inhibitor    35634
# 1431                                    inhibitor    35222
# 1432                     prostaglandin antagonist    49023
# 1433               platelet aggregation inhibitor    50427
# 1434  EC 3.2.1.18 (exo-alpha-sialidase) inhibitor    52425
#
#                                        chebi_definition
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3     A compound or agent that combines with an enzy...
# 4     A compound or agent that combines with an enzy...
# ...                                                 ...
# 1430  An EC 1.17.3.* (oxidoreductase acting on CH or...
# 1431  A substance that diminishes the rate of a chem...
# 1432  A compound that inhibits the action of prostag...
# 1433  A drug or agent which antagonizes or impairs a...
# 1434  An antiviral drug targeted at influenza viruse...
#
# [1435 rows x 6 columns]

# %% [markdown]
# # Abriendo el modelo GloVe entrenado en Wikipedia

# %%
# Cargando el embedding en memoria
embeddings_index = dict()

# Definición de la matriz de embedding
embeddings_matrix = list()

# Definición del diccionario de decodificación de palabras
idx2word = dict()

# Abriendo el archivo
with open('C:/Users/Chris-Brota/Desktop/glove.6b/glove.6B.100d.txt', 'r', encoding='utf8') as file:
    for num, line in enumerate(file):
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
        embeddings_matrix.append(coefs)
        idx2word[num] = word

# Pasando a array
embeddings_matrix = np.array(embeddings_matrix)

print(f'Vector de {len(embeddings_index)} palabras cargadas.')
# Out:
# Vector de 400001 palabras cargadas.

# %%
print(embeddings_index.get('citric'))
# Out:
# [ 0.28123   0.19583   0.06453  -0.13524   0.99726  -0.19329  -0.48548
#   0.43083  -0.16015  -0.12496  -0.5319    0.57561  -0.5881    0.085808
#  -0.0859    0.75721  -1.1515   -0.084785  0.65576   0.064682  0.067194
#  -1.1096    0.92557   0.57395  -0.34474   0.37906  -0.82575  -0.55303
#  -0.58417   0.044774  0.76227   0.75636  -0.45388  -0.8378   -0.39259
#  -0.3134    0.29243   0.025914  1.0914   -0.13309   0.57329  -0.12037
#  -0.90361  -0.91887   1.013     1.276    -0.31055  -0.86031  -0.45764
#  -0.35792  -0.34129  -0.64878  -0.21554  -0.32376  -0.75714   0.80563
#  -1.143     0.128    -0.34669  -0.40518  -0.031299 -0.63768  -0.35624
#  -0.28367   0.73029  -0.47432   0.84953  -1.1061    0.046679 -1.1738
#  -0.4851    0.45272   0.16722   0.35547  -0.27191  -0.26114   0.21498
#  -0.79119  -0.75023  -0.63608   0.068707 -0.46095  -0.44356   0.52749
#  -0.32422   0.77409  -0.81332   0.1544   -0.40902   0.4267   -0.59445
#  -0.10446  -1.2722   -0.76292   0.6785   -0.43202  -0.19278  -0.26015
#   0.93397   0.54029 ]

# %% [markdown]
# # Procesando las etiquetas

# %%
def preprocessing_text(text):
    # Remover URLs con una expresión regular
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    text = url_pattern.sub(r'', text)

    # Remover emails
    text = re.sub('\S*@\S*\s?', '', text)

    # Remover caracteres no alfabéticos
    text = re.sub("[^A-Za-z\-\s]+", "", text)
    
    # Transformar guiones en espacios
    text = re.sub('\-+', ' ', text)
    
    # Remover caracteres de espacio mayor a 1
    text = re.sub('\s+', ' ', text)
    
    # Pasando todo a minúscula
    text = text.lower()
    
    return text


# Definición de la lista que almacenará los nombres
names = list()
for text in df['name']:
    preprocessed_text = preprocessing_text(text)
    names.append(preprocessed_text)
    print(text, '\t', preprocessed_text)
# Out:
# (+)-inotropic 	  inotropic
# (-)-chronotropic 	  chronotropic
# (-)-inotropic 	  inotropic
# 11beta-hydroxysteroid-dehydrogenase inhibitor 	 beta hydroxysteroid dehydrogenase inhibitor
# 12-lipoxygenase inhibitor 	  lipoxygenase inhibitor
# 17beta-hydroxysteroid-dehydrogenase inhibitor 	 beta hydroxysteroid dehydrogenase inhibitor
# 5alpha-reductase inhibitor 	 alpha reductase inhibitor
# 5-hydroxyeicosatetraenoic-acid inhibitor 	  hydroxyeicosatetraenoic acid inhibitor
# 5-hydroxytryptamine inhibitor 	  hydroxytryptamine inhibitor
# 5-lipoxygenase inhibitor 	  lipoxygenase inhibitor
# 8-hydroxyeicosatetraenoic-acid inhibitor 	  hydroxyeicosatetraenoic acid inhibitor
# beta inhibitor 	 beta inhibitor
# abortifacient 	 abortifacient
# absorbent 	 absorbent
# acantholytic 	 acantholytic
# acaricide 	 acaricide
# acarifuge 	 acarifuge
# angiotensin converting enzyme inhibitor 	 angiotensin converting enzyme inhibitor
# acetyl-CoA-carboxylase inhibitor 	 acetyl coa carboxylase inhibitor
# acetylcholinergic 	 acetylcholinergic
# acetylcholinesterase inhibitor 	 acetylcholinesterase inhibitor
# acidifier 	 acidifier
# acidulant 	 acidulant
# acnegenic 	 acnegenic
# adaptogenic 	 adaptogenic
# addictive 	 addictive
# additive 	 additive
# adenosine antagonist 	 adenosine antagonist
# adenylate-cyclase inhibitor 	 adenylate cyclase inhibitor
# adjuvant 	 adjuvant
# adrenergic 	 adrenergic
# aedifuge 	 aedifuge
# advanced glycation end products inhibitor 	 advanced glycation end products inhibitor
# aggregant 	 aggregant
# aryl-hydrocarbon-hydroxylase inhibitor 	 aryl hydrocarbon hydroxylase inhibitor
# serine/threonine kinase inhibitor 	 serinethreonine kinase inhibitor
# albuminurigenic 	 albuminurigenic
# alcohol dehydrogenase inhibitor 	 alcohol dehydrogenase inhibitor
# aldehyde-oxidase inhibitor 	 aldehyde oxidase inhibitor
# aldose reductase inhibitor 	 aldose reductase inhibitor
# allelochemic 	 allelochemic
# allelopathic 	 allelopathic
# allergenic 	 allergenic
# alpha-amylase inhibitor 	 alpha amylase inhibitor
# alpha-glucosidase inhibitor 	 alpha glucosidase inhibitor
# alpha-reductase inhibitor 	 alpha reductase inhibitor
# amblyopic 	 amblyopic
# amebicide 	 amebicide
# amnesigenic 	 amnesigenic
# amphetaminagenic 	 amphetaminagenic
# amphiestrogenic 	 amphiestrogenic
# amphiglycemic 	 amphiglycemic
# amphitensive 	 amphitensive
# anabolic 	 anabolic
# analeptic 	 analeptic
# analgesic 	 analgesic
# anaphrodisiac 	 anaphrodisiac
# anaphylactic 	 anaphylactic
# ancylostomicide 	 ancylostomicide
# androgenic 	 androgenic
# anemiagenic 	 anemiagenic
# anesthetic 	 anesthetic
# angiogenic 	 angiogenic
# angiotensin receptor blocker 	 angiotensin receptor blocker
# anhydrotic 	 anhydrotic
# ankylostomacide 	 ankylostomacide
# anorectic 	 anorectic
# anorexic 	 anorexic
# autonomic nervous system paralytic 	 autonomic nervous system paralytic
# autonomic nervous system stimulant 	 autonomic nervous system stimulant
# ant repellent 	 ant repellent
# anti helmintic 	 anti helmintic
# anti 5-hydroxytryptamine 	 anti hydroxytryptamine
# anti LDL 	 anti ldl
# anti acetylcholine 	 anti acetylcholine
# anti acetylcholinesterase 	 anti acetylcholinesterase
# anti acid 	 anti acid
# anti acne 	 anti acne
# anti acrocyanotic 	 anti acrocyanotic
# anti acrodermatitic 	 anti acrodermatitic
# anti acrodynic 	 anti acrodynic
# anti acromegalic 	 anti acromegalic
# anti ADD 	 anti add
# anti Addisonian 	 anti addisonian
# anti adenoma carcinogenic 	 anti adenoma carcinogenic
# anti adenomic 	 anti adenomic
# anti adenoviral 	 anti adenoviral
# anti adenovirus 	 anti adenovirus
# anti adhesive 	 anti adhesive
# anti adrenalinic 	 anti adrenalinic
# anti adrenergic 	 anti adrenergic
# anti aflatoxin 	 anti aflatoxin
# anti advanced glycation end products 	 anti advanced glycation end products
# anti aggregant 	 anti aggregant
# anti aging 	 anti aging
# anti AIDS 	 anti aids
# anti akathisic 	 anti akathisic
# anti alcoholic 	 anti alcoholic
# anti aldosteronic 	 anti aldosteronic
# anti alkali 	 anti alkali
# anti alkalotic 	 anti alkalotic
# anti allergenic 	 anti allergenic
# anti allergic 	 anti allergic
# anti alopecic 	 anti alopecic
# anti Alzheimeran 	 anti alzheimeran
# anti amblyopic 	 anti amblyopic
# anti amebic 	 anti amebic
# anti amnesic 	 anti amnesic
# anti amyloid-beta 	 anti amyloid beta
# anti anacarditic 	 anti anacarditic
# anti anaphylactic 	 anti anaphylactic
# anti androgenic 	 anti androgenic
# anti anemic 	 anti anemic
# anti anginal 	 anti anginal
# anti angiogenic 	 anti angiogenic
# anti angiotensic 	 anti angiotensic
# anti anorectic 	 anti anorectic
# anti anorexic 	 anti anorexic
# anti anoxic 	 anti anoxic
# anti anxiety 	 anti anxiety
# anti apertif 	 anti apertif
# anti aphthic 	 anti aphthic
# anti apneic 	 anti apneic
# anti apoplectic 	 anti apoplectic
# anti apoptotic 	 anti apoptotic
# anti appetant 	 anti appetant
# anti arabiflavinotic 	 anti arabiflavinotic
# anti arachidonate 	 anti arachidonate
# anti arrhythmic 	 anti arrhythmic
# anti arteriosclerotic 	 anti arteriosclerotic
# anti arthritic 	 anti arthritic
# anti asphyctic 	 anti asphyctic
# ant iasthenic 	 ant iasthenic
# anti asthmatic 	 anti asthmatic
# anti ataxic 	 anti ataxic
# anti atherogenic 	 anti atherogenic
# anti atheromic 	 anti atheromic
# anti atherosclerotic 	 anti atherosclerotic
# anti atherotic 	 anti atherotic
# anti autistic 	 anti autistic
# anti azotemic 	 anti azotemic
# anti bacillary 	 anti bacillary
# anti bacillus 	 anti bacillus
# anti backache 	 anti backache
# anti bacterial 	 anti bacterial
# anti beriberi 	 anti beriberi
# antibiotic 	 antibiotic
# anti benign prostatic hyperplasia 	 anti benign prostatic hyperplasia
# anti bradiquinic 	 anti bradiquinic
# anti bradyarrhythmic 	 anti bradyarrhythmic
# anti bradycardic 	 anti bradycardic
# anti bradykinetic 	 anti bradykinetic
# anti bradykinic 	 anti bradykinic
# anti bronchitic 	 anti bronchitic
# anti bronchoconstrictor 	 anti bronchoconstrictor
# anti brucellosic 	 anti brucellosic
# anti burn 	 anti burn
# anti calculic 	 anti calculic
# anti cancer 	 anti cancer
# anti capillary-fragility 	 anti capillary fragility
# anti carcinogenic 	 anti carcinogenic
# anti carcinomic 	 anti carcinomic
# anti cardiospasmic 	 anti cardiospasmic
# anti caries 	 anti caries
# anti cariogenic 	 anti cariogenic
# anti carpal-tunnel 	 anti carpal tunnel
# anti cataleptic 	 anti cataleptic
# anti cataract 	 anti cataract
# anti catarrh 	 anti catarrh
# anti cellulitic 	 anti cellulitic
# anti cephalagic 	 anti cephalagic
# anti cerebrotic 	 anti cerebrotic
# anti cervicaldysplasic 	 anti cervicaldysplasic
# anti CFS 	 anti cfs
# anti cheilitic 	 anti cheilitic
# anti cheilotic 	 anti cheilotic
# anti chilblain 	 anti chilblain
# anti cholecystosic 	 anti cholecystosic
# anti choleretic 	 anti choleretic
# anti cholestatic 	 anti cholestatic
# anti cholesteremic 	 anti cholesteremic
# anti cholesterogenic 	 anti cholesterogenic
# anti cholinergic 	 anti cholinergic
# anti cholinesterase 	 anti cholinesterase
# anti chorea 	 anti chorea
# anti choreic 	 anti choreic
# anti cirrhotic 	 anti cirrhotic
# anti clastogen 	 anti clastogen
# anti claudificant 	 anti claudificant
# anti climacteric 	 anti climacteric
# anti coagulant 	 anti coagulant
# anti coccidioid 	 anti coccidioid
# anti coeliac 	 anti coeliac
# anti cold 	 anti cold
# anti colic 	 anti colic
# anti colitic 	 anti colitic
# anti collagenic 	 anti collagenic
# anti collegenase 	 anti collegenase
# anti colonospasmic 	 anti colonospasmic
# anti complement 	 anti complement
# anti complementary 	 anti complementary
# anti conjunctivitic 	 anti conjunctivitic
# anti constrictive 	 anti constrictive
# anti convulsant 	 anti convulsant
# anti corneitic 	 anti corneitic
# anti corneotic 	 anti corneotic
# anti coronary 	 anti coronary
# anti corpus-luteum 	 anti corpus luteum
# anti Crohn's 	 anti crohns
# anti C-reactive-protein 	 anti c reactive protein
# anti cryptococcic 	 anti cryptococcic
# anti CTS 	 anti cts
# anti CVI 	 anti cvi
# anti CVS 	 anti cvs
# anti cystinuric 	 anti cystinuric
# anti cystitic 	 anti cystitic
# anti cytomegalovirus 	 anti cytomegalovirus
# anti cytotoxic 	 anti cytotoxic
# anti dandruff 	 anti dandruff
# anti decubitic 	 anti decubitic
# anti deliriant 	 anti deliriant
# anti dementia 	 anti dementia
# anti depressant 	 anti depressant
# anti dermatic 	 anti dermatic
# anti dermatitic 	 anti dermatitic
# anti dermatophytic 	 anti dermatophytic
# anti dermatotic 	 anti dermatotic
# anti diabetic 	 anti diabetic
# anti diarrheic 	 anti diarrheic
# anti dipsomanic 	 anti dipsomanic
# anti discitic 	 anti discitic
# anti discotic 	 anti discotic
# anti diuretic 	 anti diuretic
# anti-DNA 	 anti dna
# anti dopaminergic 	 anti dopaminergic
# antidote 	 antidote
# anti drepanocytic 	 anti drepanocytic
# anti dysenteric 	 anti dysenteric
# anti dysgeuzic 	 anti dysgeuzic
# anti dyskinetic 	 anti dyskinetic
# anti dysmenorrheic 	 anti dysmenorrheic
# anti dyspeptic 	 anti dyspeptic
# anti dysphagic 	 anti dysphagic
# anti ear-wax 	 anti ear wax
# anti Epstein-Barr virus 	 anti epstein barr virus
# anti ecchymotic 	 anti ecchymotic
# anti eczemic 	 anti eczemic
# anti edemic 	 anti edemic
# anti eicosanoid 	 anti eicosanoid
# anti elastase 	 anti elastase
# anti elleptic 	 anti elleptic
# anti embolic 	 anti embolic
# anti emetic 	 anti emetic
# anti emphysemic 	 anti emphysemic
# anti encephalitic 	 anti encephalitic
# anti encephalopathic 	 anti encephalopathic
# anti endoccytotic 	 anti endoccytotic
# anti endometriotic 	 anti endometriotic
# anti endotoxic 	 anti endotoxic
# anti enteritic 	 anti enteritic
# anti enterococcic 	 anti enterococcic
# anti enterotic 	 anti enterotic
# anti enuretic 	 anti enuretic
# anti enzymatic 	 anti enzymatic
# anti epileptic 	 anti epileptic
# anti episiotomic 	 anti episiotomic
# anti epitheleomic 	 anti epitheleomic
# anti erythemic 	 anti erythemic
# anti escherichic 	 anti escherichic
# anti esherichic 	 anti esherichic
# anti esophagitic 	 anti esophagitic
# anti estrogenic 	 anti estrogenic
# anti exudative 	 anti exudative
# anti fatigue 	 anti fatigue
# anti feedant 	 anti feedant
# anti fertility 	 anti fertility
# anti fibrinolytic 	 anti fibrinolytic
# anti fibromyalgic 	 anti fibromyalgic
# anti fibrosarcomic 	 anti fibrosarcomic
# anti fibrositic 	 anti fibrositic
# anti fibrotic 	 anti fibrotic
# anti filarial 	 anti filarial
# anti flatulent 	 anti flatulent
# anti flu 	 anti flu
# anti fumitory 	 anti fumitory
# anti furuncular 	 anti furuncular
# anti galactagogue 	 anti galactagogue
# anti gallstone 	 anti gallstone
# anti gargantitic 	 anti gargantitic
# anti gastric 	 anti gastric
# anti gastrisecretogogic 	 anti gastrisecretogogic
# anti gastritic 	 anti gastritic
# anti gastrotic 	 anti gastrotic
# antigenic 	 antigenic
# anti genotoxic 	 anti genotoxic
# anti giardial 	 anti giardial
# anti gibberellin 	 anti gibberellin
# anti gingivitic 	 anti gingivitic
# anti glaucomic 	 anti glaucomic
# anti gliomic 	 anti gliomic
# anti glossitic 	 anti glossitic
# anti glucuronidase 	 anti glucuronidase
# anti glutamaergic 	 anti glutamaergic
# anti glycosation 	 anti glycosation
# anti glycosuric 	 anti glycosuric
# anti goiter 	 anti goiter
# anti gonadotrophic 	 anti gonadotrophic
# anti gonadotropic 	 anti gonadotropic
# anti gout 	 anti gout
# anti granular 	 anti granular
# anti granulocytopenic 	 anti granulocytopenic
# anti grey 	 anti grey
# anti glucose-tolerance-factor 	 anti glucose tolerance factor
# anti halitosic 	 anti halitosic
# anti hangover 	 anti hangover
# anti heartburn 	 anti heartburn
# anti helicobacter 	 anti helicobacter
# anti hematuric 	 anti hematuric
# anti hemolytic 	 anti hemolytic
# anti hemophilic 	 anti hemophilic
# anti hemorrhagic 	 anti hemorrhagic
# anti hemorrhoidal 	 anti hemorrhoidal
# anti hepatitic 	 anti hepatitic
# anti hepatoadenomic 	 anti hepatoadenomic
# anti hepatocarcinogenic 	 anti hepatocarcinogenic
# anti hepatomic 	 anti hepatomic
# anti hepatotic 	 anti hepatotic
# anti hepatotoxic 	 anti hepatotoxic
# anti herpetic 	 anti herpetic
# anti hiccup 	 anti hiccup
# anti histaminic 	 anti histaminic
# anti histoplasmotic 	 anti histoplasmotic
# anti HIV 	 anti hiv
# anti HIV-integrase 	 anti hiv integrase
# anti homocysteine 	 anti homocysteine
# anti homocystinuric 	 anti homocystinuric
# anti hot-flash 	 anti hot flash
# anti hydrocoele 	 anti hydrocoele
# anti hydrophobic 	 anti hydrophobic
# anti hyperactivity 	 anti hyperactivity
# anti hyperammonemic 	 anti hyperammonemic
# anti hypercholesterolemic 	 anti hypercholesterolemic
# anti hyperglycemic 	 anti hyperglycemic
# anti hyperinsulinemic 	 anti hyperinsulinemic
# anti hyperkeratotic 	 anti hyperkeratotic
# anti hyperkinetic 	 anti hyperkinetic
# anti hyperleptinemic 	 anti hyperleptinemic
# anti hyperlipidemic 	 anti hyperlipidemic
# anti hyperlipoproteinaemic 	 anti hyperlipoproteinaemic
# anti hyperparathyroidic 	 anti hyperparathyroidic
# anti hyperpigmentative 	 anti hyperpigmentative
# anti hypertensive 	 anti hypertensive
# anti hyperthyroid 	 anti hyperthyroid
# anti hyperventilation 	 anti hyperventilation
# anti hypoglycemic 	 anti hypoglycemic
# anti hypogonadic 	 anti hypogonadic
# anti hypotensive 	 anti hypotensive
# anti hypoxic 	 anti hypoxic
# anti hysteric 	 anti hysteric
# anti ichthyosic 	 anti ichthyosic
# anti ichythyotic 	 anti ichythyotic
# anti ielus 	 anti ielus
# anti ileus 	 anti ileus
# anti implantation 	 anti implantation
# anti impotence 	 anti impotence
# anti incontinence 	 anti incontinence
# anti infarctal 	 anti infarctal
# anti infective 	 anti infective
# anti infertility 	 anti infertility
# anti inflammatory 	 anti inflammatory
# anti insomniac 	 anti insomniac
# anti insomnic 	 anti insomnic
# anti insulinogenic 	 anti insulinogenic
# anti integrase 	 anti integrase
# anti iritic 	 anti iritic
# anti ischaemic 	 anti ischaemic
# anti ischemic 	 anti ischemic
# anti jet-lag 	 anti jet lag
# anti keratitic 	 anti keratitic
# anti keratotic 	 anti keratotic
# anti keshan 	 anti keshan
# anti ketotic 	 anti ketotic
# anti klebsiellic 	 anti klebsiellic
# anti lactagogue 	 anti lactagogue
# anti lactobacillic 	 anti lactobacillic
# anti laryngitic 	 anti laryngitic
# anti legionella 	 anti legionella
# anti leishmanic 	 anti leishmanic
# anti lepric 	 anti lepric
# anti leprotic 	 anti leprotic
# anti lethargic 	 anti lethargic
# anti leucodermic 	 anti leucodermic
# anti leukemic 	 anti leukemic
# anti leukodermic 	 anti leukodermic
# anti leukonychic 	 anti leukonychic
# anti leukopenic 	 anti leukopenic
# anti leukoplakic 	 anti leukoplakic
# anti leukorrheic 	 anti leukorrheic
# anti leukotriene 	 anti leukotriene
# anti leukotriene-B4 	 anti leukotriene b
# anti leukotriene-D4 	 anti leukotriene d
# anti leukotrienogenic 	 anti leukotrienogenic
# anti lipedemic 	 anti lipedemic
# anti lipemic 	 anti lipemic
# anti lipogenic 	 anti lipogenic
# anti lipolytic 	 anti lipolytic
# anti lipoperoxidant 	 anti lipoperoxidant
# anti listeria 	 anti listeria
# anti lithic 	 anti lithic
# anti lupus 	 anti lupus
# anti Lyme 	 anti lyme
# anti lymphedemic 	 anti lymphedemic
# anti lymphocytic 	 anti lymphocytic
# anti lymphomic 	 anti lymphomic
# anti maculitic 	 anti maculitic
# anti malarial 	 anti malarial
# anti mange 	 anti mange
# anti manic 	 anti manic
# anti mastalgic 	 anti mastalgic
# anti mastitic 	 anti mastitic
# anti MD 	 anti md
# anti multidrug resistance 	 anti multidrug resistance
# anti measles 	 anti measles
# anti melanogenic 	 anti melanogenic
# anti melanomic 	 anti melanomic
# anti melasmic 	 anti melasmic
# anti Meniere's 	 anti menieres
# anti meningitic 	 anti meningitic
# anti menopausal 	 anti menopausal
# anti menorrhagic 	 anti menorrhagic
# anti metabolic 	 anti metabolic
# anti metabolite 	 anti metabolite
# anti metaplastic 	 anti metaplastic
# anti metastatic 	 anti metastatic
# anti metrorrhagic 	 anti metrorrhagic
# anti microbial 	 anti microbial
# anti migraine 	 anti migraine
# anti mite 	 anti mite
# anti mitochondrial 	 anti mitochondrial
# anti mitogenic 	 anti mitogenic
# anti mitotic 	 anti mitotic
# anti mitral-valve-prolapse 	 anti mitral valve prolapse
# anti mononuccleotic 	 anti mononuccleotic
# anti morning sickness 	 anti morning sickness
# anti morphinic 	 anti morphinic
# anti morphinistic 	 anti morphinistic
# anti methicillin-resistant Staphylococcus aureus 	 anti methicillin resistant staphylococcus aureus
# anti monosodium-glutamate 	 anti monosodium glutamate
# anti monosodium-glutamate-sensitivity 	 anti monosodium glutamate sensitivity
# anti muscarinic 	 anti muscarinic
# anti mutagenic 	 anti mutagenic
# anti mutilation 	 anti mutilation
# anti myalgic 	 anti myalgic
# anti myasthenic 	 anti myasthenic
# anti mycoplasmotic 	 anti mycoplasmotic
# anti mycotic 	 anti mycotic
# anti myelotoxic 	 anti myelotoxic
# anti myoatrophic 	 anti myoatrophic
# anti myocarditic 	 anti myocarditic
# anti myoclonic 	 anti myoclonic
# anti myocontractant 	 anti myocontractant
# anti myopic 	 anti myopic
# anti narcotic 	 anti narcotic
# anti nauseant 	 anti nauseant
# anti neoplastic 	 anti neoplastic
# anti nephritic 	 anti nephritic
# anti nephrolytic 	 anti nephrolytic
# anti nesidioblastosic 	 anti nesidioblastosic
# anti neuralgic 	 anti neuralgic
# anti neuramidase 	 anti neuramidase
# anti neurasthenic 	 anti neurasthenic
# anti neuritic 	 anti neuritic
# anti neuroblastomic 	 anti neuroblastomic
# anti neurogenic 	 anti neurogenic
# anti neuroleptic 	 anti neuroleptic
# anti neuropathic 	 anti neuropathic
# anti neurotic 	 anti neurotic
# anti NF-kappa-B 	 anti nf kappa b
# anti nicotinic 	 anti nicotinic
# anti nitrosaminic 	 anti nitrosaminic
# anti nitrosating 	 anti nitrosating
# anti nitrosic 	 anti nitrosic
# anti NKC 	 anti nkc
# anti nociceptive 	 anti nociceptive
# anti nyctalopic 	 anti nyctalopic
# anti obesity 	 anti obesity
# anti odontalgic 	 anti odontalgic
# anti oncychomycotic 	 anti oncychomycotic
# anti onychogryphotic 	 anti onychogryphotic
# anti onychyotic 	 anti onychyotic
# anti ophidic 	 anti ophidic
# anti ophthalmic 	 anti ophthalmic
# anti orchitic 	 anti orchitic
# anti osteoarthritic 	 anti osteoarthritic
# anti osteoporotic 	 anti osteoporotic
# anti osteosclerotic 	 anti osteosclerotic
# anti osteotic 	 anti osteotic
# anti otitic 	 anti otitic
# anti ototic 	 anti ototic
# anti oxalate 	 anti oxalate
# anti oxaluric 	 anti oxaluric
# antioxidant 	 antioxidant
# anti ozenic 	 anti ozenic
# anti platelet aggregation factor 	 anti platelet aggregation factor
# anti pancreatitic 	 anti pancreatitic
# anti panniculopathic 	 anti panniculopathic
# anti papillomic 	 anti papillomic
# anti parasitic 	 anti parasitic
# anti Parkinsonian 	 anti parkinsonian
# anti parotitic 	 anti parotitic
# anti pellagric 	 anti pellagric
# anti peptic 	 anti peptic
# anti periodic 	 anti periodic
# anti periodontal 	 anti periodontal
# anti periodontic 	 anti periodontic
# anti periodontitic 	 anti periodontitic
# anti peristaltic 	 anti peristaltic
# anti permeability 	 anti permeability
# anti peroxidant 	 anti peroxidant
# anti peroxidative 	 anti peroxidative
# anti peroxynitrite 	 anti peroxynitrite
# anti perspirant 	 anti perspirant
# anti pertussic 	 anti pertussic
# anti pertussive 	 anti pertussive
# anti prostaglandin-E2 	 anti prostaglandin e
# anti pharyngitic 	 anti pharyngitic
# anti phenylketonuric 	 anti phenylketonuric
# anti photophobic 	 anti photophobic
# anti pityriasic 	 anti pityriasic
# anti plantar 	 anti plantar
# anti plaque 	 anti plaque
# anti plasmodial 	 anti plasmodial
# anti platelet 	 anti platelet
# anti premenstrual syndrome 	 anti premenstrual syndrome
# anti pneumonic 	 anti pneumonic
# anti podagric 	 anti podagric
# anti podriac 	 anti podriac
# anti polio 	 anti polio
# anti poliomyelitic 	 anti poliomyelitic
# anti polyp 	 anti polyp
# anti porphyric 	 anti porphyric
# anti predatory 	 anti predatory
# anti proctalgic 	 anti proctalgic
# anti progestational 	 anti progestational
# anti progesterone 	 anti progesterone
# anti prolactin 	 anti prolactin
# anti proliferant 	 anti proliferant
# anti proliferative 	 anti proliferative
# anti promoter 	 anti promoter
# anti prostaglandin 	 anti prostaglandin
# anti prostanoid 	 anti prostanoid
# anti prostat adenomic 	 anti prostat adenomic
# anti prostatitic 	 anti prostatitic
# anti prostatotic 	 anti prostatotic
# anti proteinigenic 	 anti proteinigenic
# anti proteolytic 	 anti proteolytic
# anti protozoal 	 anti protozoal
# anti pruritic 	 anti pruritic
# anti prostate-specific-antigen 	 anti prostate specific antigen
# anti pseudomonic 	 anti pseudomonic
# anti psittacotic 	 anti psittacotic
# anti psoriac 	 anti psoriac
# anti psoriatic 	 anti psoriatic
# anti psychotic 	 anti psychotic
# anti pulmonotic 	 anti pulmonotic
# anti purpuric 	 anti purpuric
# anti pyretic 	 anti pyretic
# anti pyruvetic 	 anti pyruvetic
# anti rabies 	 anti rabies
# anti rachitic 	 anti rachitic
# anti radiation 	 anti radiation
# anti radicular 	 anti radicular
# anti Raynaud's 	 anti raynauds
# anti renitic 	 anti renitic
# anti reproductive 	 anti reproductive
# anti reserpine 	 anti reserpine
# anti respirotic 	 anti respirotic
# anti retardation 	 anti retardation
# anti retinitic 	 anti retinitic
# anti retinopathic 	 anti retinopathic
# anti retinotic 	 anti retinotic
# anti retroviral 	 anti retroviral
# anti Reye's 	 anti reyes
# anti rheumatalgic 	 anti rheumatalgic
# anti rheumatic 	 anti rheumatic
# anti rheumatitic 	 anti rheumatitic
# anti rhinitic 	 anti rhinitic
# anti rhinoviral 	 anti rhinoviral
# anti rickettsial 	 anti rickettsial
# anti-RNA 	 anti rna
# anti salmonella 	 anti salmonella
# anti sarcomic 	 anti sarcomic
# anti schistosomiac 	 anti schistosomiac
# anti schizophrenic 	 anti schizophrenic
# anti sclerodermic 	 anti sclerodermic
# anti scleromyxoedemic 	 anti scleromyxoedemic
# anti scoliotic 	 anti scoliotic
# anti scorbutic 	 anti scorbutic
# anti scotomic 	 anti scotomic
# anti seborrheic 	 anti seborrheic
# anti secretory 	 anti secretory
# anti senility 	 anti senility
# anti septic 	 anti septic
# anti septic-shock 	 anti septic shock
# anti seratogenic 	 anti seratogenic
# anti serotonergic 	 anti serotonergic
# anti serotonic 	 anti serotonic
# anti serotonin 	 anti serotonin
# anti serotoninic 	 anti serotoninic
# anti shigellic 	 anti shigellic
# anti shingles 	 anti shingles
# anti shock 	 anti shock
# anti sialogogue 	 anti sialogogue
# anti sickling 	 anti sickling
# anti silicotic 	 anti silicotic
# anti sindhis 	 anti sindhis
# anti sinusitic 	 anti sinusitic
# anti spare-tire 	 anti spare tire
# anti spasmodic 	 anti spasmodic
# anti spasmophilic 	 anti spasmophilic
# anti spastic 	 anti spastic
# anti spermatogenic 	 anti spermatogenic
# anti spina-bifida 	 anti spina bifida
# anti sprout 	 anti sprout
# anti sprue 	 anti sprue
# anti staph 	 anti staph
# anti staphylococcic 	 anti staphylococcic
# anti steatotic 	 anti steatotic
# anti sterility 	 anti sterility
# anti stomatitic 	 anti stomatitic
# anti streptococcic 	 anti streptococcic
# anti stress 	 anti stress
# anti stroke 	 anti stroke
# anti substance-P 	 anti substance p
# anti sunburn 	 anti sunburn
# anti superoxidogenic 	 anti superoxidogenic
# anti syncopic 	 anti syncopic
# anti syndrome-X 	 anti syndrome x
# anti tachycardic 	 anti tachycardic
# anti tartar 	 anti tartar
# anti testicular 	 anti testicular
# anti testosterone 	 anti testosterone
# anti tetanic 	 anti tetanic
# anti TGF-beta 	 anti tgf beta
# anti thalassemic 	 anti thalassemic
# anti thiamin 	 anti thiamin
# anti thrombic 	 anti thrombic
# anti thrombogenic 	 anti thrombogenic
# anti thrombophlebitic 	 anti thrombophlebitic
# anti thrombotic 	 anti thrombotic
# anti thromboxane 	 anti thromboxane
# anti thromboxane-B2 	 anti thromboxane b
# anti thyreotropic 	 anti thyreotropic
# anti thyroid 	 anti thyroid
# anti thyrotoxic 	 anti thyrotoxic
# anti tic 	 anti tic
# anti tinnitic 	 anti tinnitic
# anti TMJ 	 anti tmj
# anti TNF 	 anti tnf
# anti tonsilitic 	 anti tonsilitic
# anti topoisomerase-II 	 anti topoisomerase ii
# anti torticollic 	 anti torticollic
# anti Tourette's 	 anti tourettes
# anti toxemic 	 anti toxemic
# anti toxoplasmotic 	 anti toxoplasmotic
# anti tremor 	 anti tremor
# anti trichinosic 	 anti trichinosic
# anti triglyceride 	 anti triglyceride
# anti trypanosomic 	 anti trypanosomic
# anti tubercular 	 anti tubercular
# anti tuberculic 	 anti tuberculic
# antitumor 	 antitumor
# antitumor promoter 	 antitumor promoter
# anti tussive 	 anti tussive
# anti tympanitic 	 anti tympanitic
# anti ulcer 	 anti ulcer
# anti ulcerogenic 	 anti ulcerogenic
# anti urease 	 anti urease
# anti uremic 	 anti uremic
# anti urethrotic 	 anti urethrotic
# anti uricosuric 	 anti uricosuric
# anti uterocontractant 	 anti uterocontractant
# anti urinary-tract-infection 	 anti urinary tract infection
# anti uveitic 	 anti uveitic
# anti vaccinia 	 anti vaccinia
# anti vaginitic 	 anti vaginitic
# anti varicose 	 anti varicose
# anti vertigo 	 anti vertigo
# anti viral 	 anti viral
# anti vitiligic 	 anti vitiligic
# anti vulvitic 	 anti vulvitic
# anti wart 	 anti wart
# anti wrinkle 	 anti wrinkle
# anti X-radiation 	 anti x radiation
# anti xerophthalmic 	 anti xerophthalmic
# anti xerotic 	 anti xerotic
# anti yeast 	 anti yeast
# anxiolytic 	 anxiolytic
# activator-protein-1 inhibitor 	 activator protein inhibitor
# aphicide 	 aphicide
# aphidifuge 	 aphidifuge
# aphrodisiac 	 aphrodisiac
# apifuge 	 apifuge
# apoptotic 	 apoptotic
# aromatase inhibitor 	 aromatase inhibitor
# arrhythmigenic 	 arrhythmigenic
# artemicide 	 artemicide
# arteriodilator 	 arteriodilator
# arylamine-N-acetyltransferase inhibitor 	 arylamine n acetyltransferase inhibitor
# ascaricide 	 ascaricide
# asthma preventive 	 asthma preventive
# astringent 	 astringent
# ataractic 	 ataractic
# ataxigenic 	 ataxigenic
# atherogenic 	 atherogenic
# ATPase inhibitor 	 atpase inhibitor
# ATPase stimulant 	 atpase stimulant
# attifuge 	 attifuge
# autotoxic 	 autotoxic
# avicide 	 avicide
# avifuge 	 avifuge
# bactericide 	 bactericide
# bacteriophagicide 	 bacteriophagicide
# bacteriostatic 	 bacteriostatic
# bacteristat 	 bacteristat
# barbituate-synergist 	 barbituate synergist
# beta-adrenergic receptor blocker 	 beta adrenergic receptor blocker
# beta-blocker 	 beta blocker
# beta-glucuronidase inhibitor 	 beta glucuronidase inhibitor
# bifidogenic 	 bifidogenic
# bilirubinolytic 	 bilirubinolytic
# bitter 	 bitter
# bradycardiac 	 bradycardiac
# bradycardic 	 bradycardic
# bronchoconstrictor 	 bronchoconstrictor
# bronchodilator 	 bronchodilator
# bronchomucolytic 	 bronchomucolytic
# bronchomucotropic 	 bronchomucotropic
# bronchoprotectant 	 bronchoprotectant
# broncho elaxant 	 broncho elaxant
# bronchorrheic 	 bronchorrheic
# bronchosedative 	 bronchosedative
# bronchospasmolytic 	 bronchospasmolytic
# bronchostimulant 	 bronchostimulant
# bruchifuge 	 bruchifuge
# bruchiphobe 	 bruchiphobe
# bufocide 	 bufocide
# calcium antagonist 	 calcium antagonist
# calcium channel blocker 	 calcium channel blocker
# calcium-sparing 	 calcium sparing
# calmodulin antagonist 	 calmodulin antagonist
# cAMP inhibitor 	 camp inhibitor
# cAMP-phosphodiesterase inhibitor 	 camp phosphodiesterase inhibitor
# cancer preventive 	 cancer preventive
# Candida-secreted-aspartyl-proteinase inhibitor 	 candida secreted aspartyl proteinase inhibitor
# candidicide 	 candidicide
# candidistat 	 candidistat
# capillarifortificant 	 capillarifortificant
# capillarigenic 	 capillarigenic
# capillariprotective 	 capillariprotective
# capillaritonic 	 capillaritonic
# carcinogenic 	 carcinogenic
# carcinostatic 	 carcinostatic
# cardiac 	 cardiac
# cardioactive 	 cardioactive
# cardiodepressant 	 cardiodepressant
# cardiomyopathogenic 	 cardiomyopathogenic
# cardioparalytic 	 cardioparalytic
# cardioprotective 	 cardioprotective
# cardiosedative 	 cardiosedative
# cardiotonic 	 cardiotonic
# cardiotoxic 	 cardiotoxic
# cardiovascular 	 cardiovascular
# carminative 	 carminative
# casein-kinase-II inhibitor 	 casein kinase ii inhibitor
# caspase-3 inducer 	 caspase inducer
# caspase-3 inhibitor 	 caspase inhibitor
# caspase-8 inducer 	 caspase inducer
# caspase-9 inhibitor 	 caspase inhibitor
# catabolic 	 catabolic
# cataractagenic 	 cataractagenic
# catechol O-methyltransferase inhibitor 	 catechol o methyltransferase inhibitor
# catecholaminogenic 	 catecholaminogenic
# cathartic 	 cathartic
# cerebrodepressant 	 cerebrodepressant
# cerebrophilic 	 cerebrophilic
# cerebroprotective 	 cerebroprotective
# cerebrostimulant 	 cerebrostimulant
# cerebrotonic 	 cerebrotonic
# cerebrotoxic 	 cerebrotoxic
# cerumenolytic 	 cerumenolytic
# cestodicide 	 cestodicide
# cGMP inhibitor 	 cgmp inhibitor
# cGMP-phosphodiesterase inhibitor 	 cgmp phosphodiesterase inhibitor
# chelator 	 chelator
# chemopreventive 	 chemopreventive
# chemopreventive inhibitor 	 chemopreventive inhibitor
# chitinolytic 	 chitinolytic
# chitosanolytic 	 chitosanolytic
# cholagogue 	 cholagogue
# choleretic 	 choleretic
# cholesterolytic 	 cholesterolytic
# choline-sparing 	 choline sparing
# cholinergic 	 cholinergic
# chronotropic 	 chronotropic
# cicatrizant 	 cicatrizant
# ciliotoxic 	 ciliotoxic
# circulatory stimulant 	 circulatory stimulant
# circulotonic 	 circulotonic
# clastogenic 	 clastogenic
# central nervous system active 	 central nervous system active
# central nervous system depressant 	 central nervous system depressant
# central nervous system inhibitor 	 central nervous system inhibitor
# central nervous system paralytic 	 central nervous system paralytic
# central nervous system sedative 	 central nervous system sedative
# central nervous system stimulant 	 central nervous system stimulant
# central nervous system toxic 	 central nervous system toxic
# coagulant 	 coagulant
# cold preventive 	 cold preventive
# coleopterifuge 	 coleopterifuge
# coleoptophile 	 coleoptophile
# collagen-sparing 	 collagen sparing
# collagenase inhibitor 	 collagenase inhibitor
# collagenic 	 collagenic
# collyrium 	 collyrium
# colorant 	 colorant
# comedogenic 	 comedogenic
# comedolytic 	 comedolytic
# congestant 	 congestant
# contraceptive 	 contraceptive
# controlled 	 controlled
# convulsant 	 convulsant
# copper antagonist 	 copper antagonist
# copper chelator 	 copper chelator
# coronarydilator 	 coronarydilator
# corrosive 	 corrosive
# corticosterogenic 	 corticosterogenic
# cosmetic 	 cosmetic
# counterirritant 	 counterirritant
# cyclooxygenase-1 inhibitor 	 cyclooxygenase inhibitor
# cyclooxygenase-2 inhibitor 	 cyclooxygenase inhibitor
# crustacicide 	 crustacicide
# culicide 	 culicide
# curare 	 curare
# cyanogenic 	 cyanogenic
# cyclin-B1 inhibitor 	 cyclin b inhibitor
# cyclin-D1 inhibitor 	 cyclin d inhibitor
# cyclooxygenase activator 	 cyclooxygenase activator
# cyclooxygenase inhibitor 	 cyclooxygenase inhibitor
# cytochrome-CYP1A1 inhibitor 	 cytochrome cypa inhibitor
# cytochrome-P450-1A1 inhibitor 	 cytochrome p a inhibitor
# cytochrome-P450-1A2 inhibitor 	 cytochrome p a inhibitor
# cytochrome-P450-2E1 inhibitor 	 cytochrome p e inhibitor
# cytochrome-p450 inducer 	 cytochrome p inducer
# cytochrome-P450 inhibitor 	 cytochrome p inhibitor
# cytochrome-p488 inducer 	 cytochrome p inducer
# cytoprotective 	 cytoprotective
# cytostatic 	 cytostatic
# cytotoxic 	 cytotoxic
# decalcifier 	 decalcifier
# decarboxylase inhibitor 	 decarboxylase inhibitor
# decongestant 	 decongestant
# degranulant 	 degranulant
# dehydrogenase inhibitor 	 dehydrogenase inhibitor
# deiodinase inhibitor 	 deiodinase inhibitor
# deliriant 	 deliriant
# delta9-desaturase inhibitor 	 delta desaturase inhibitor
# demulcent 	 demulcent
# dentifrice 	 dentifrice
# deodorant 	 deodorant
# depigmentor 	 depigmentor
# depressant 	 depressant
# depressor 	 depressor
# dermal 	 dermal
# dermatitigenic 	 dermatitigenic
# desmutagenic 	 desmutagenic
# detoxicant 	 detoxicant
# diagnostic 	 diagnostic
# diaphoretic 	 diaphoretic
# differentiator 	 differentiator
# digestive 	 digestive
# disinfectant 	 disinfectant
# diuretic 	 diuretic
# diabetic-macular-edema inhibitor 	 diabetic macular edema inhibitor
# DNA-active 	 dna active
# DNA-binder 	 dna binder
# DNA-protective 	 dna protective
# DOPA-decarboxylase inhibitor 	 dopa decarboxylase inhibitor
# dopamine-adenylate-cyclase inhibitor 	 dopamine adenylate cyclase inhibitor
# dopamine blocker 	 dopamine blocker
# dopaminergic 	 dopaminergic
# copaminigenic 	 copaminigenic
# dye 	 dye
# ecbolic 	 ecbolic
# ectoparasiticide 	 ectoparasiticide
# edemagenic 	 edemagenic
# elastase inhibitor 	 elastase inhibitor
# embryotoxic 	 embryotoxic
# emetic 	 emetic
# emmenagogue 	 emmenagogue
# emollient 	 emollient
# encephalopathic 	 encephalopathic
# endocrinactive 	 endocrinactive
# endorphinogenic 	 endorphinogenic
# energizer 	 energizer
# enterocontractant 	 enterocontractant
# enteromotility enhancer 	 enteromotility enhancer
# enterorelaxant 	 enterorelaxant
# enterotoxic 	 enterotoxic
# epidermal stimulant 	 epidermal stimulant
# epileptigenic 	 epileptigenic
# epinephrininergic 	 epinephrininergic
# estrogen receptor beta binder 	 estrogen receptor beta binder
# ergogenic 	 ergogenic
# ergotamine enhancer 	 ergotamine enhancer
# ERK1 inhibitor 	 erk inhibitor
# ERK2 inhibitor 	 erk inhibitor
# erythrocytogenic 	 erythrocytogenic
# erythrocytolytic 	 erythrocytolytic
# essential 	 essential
# estrogen agonist 	 estrogen agonist
# estrogenic 	 estrogenic
# ethanolytic 	 ethanolytic
# euphoriant 	 euphoriant
# expectorant 	 expectorant
# fatal 	 fatal
# febrifuge 	 febrifuge
# feline attractant 	 feline attractant
# FEMA 	 fema
# ferulosys-genic 	 ferulosys genic
# fetotoxic 	 fetotoxic
# fibrinolytic 	 fibrinolytic
# fistula preventive 	 fistula preventive
# flatugenic 	 flatugenic
# flatulent 	 flatulent
# flavor 	 flavor
# floral inhibitor 	 floral inhibitor
# FPTase inhibitor 	 fptase inhibitor
# fumigant 	 fumigant
# fungicide 	 fungicide
# fungiphilic 	 fungiphilic
# fungistat 	 fungistat
# fungitoxic 	 fungitoxic
# GABA antagonist 	 gaba antagonist
# GABA nergic 	 gaba nergic
# gastroirritant 	 gastroirritant
# gastroprotective 	 gastroprotective
# gastrosedative 	 gastrosedative
# gastrostimulant 	 gastrostimulant
# genotoxic 	 genotoxic
# glaucomagenic 	 glaucomagenic
# glucogonogenic 	 glucogonogenic
# glucosyl-transferase inhibitor 	 glucosyl transferase inhibitor
# glutathionalytic 	 glutathionalytic
# glutathione depleting 	 glutathione depleting
# glutathione-sparing 	 glutathione sparing
# glutathionergic 	 glutathionergic
# glutathionigenic 	 glutathionigenic
# goitrogenic 	 goitrogenic
# gonadotrophic 	 gonadotrophic
# gonadotropic 	 gonadotropic
# Gram(+)icide 	 gramicide
# Gram(-)icide 	 gram icide
# glutathione-S-transferase inducer 	 glutathione s transferase inducer
# glucuronosyltransferase inducer 	 glucuronosyltransferase inducer
# GPTase inhibitor 	 gptase inhibitor
# hallucinogen 	 hallucinogen
# hallucinogenic 	 hallucinogenic
# HDL-genic 	 hdl genic
# hematopoietic 	 hematopoietic
# heme-sparing 	 heme sparing
# hemoglobin inducer 	 hemoglobin inducer
# hemolytic 	 hemolytic
# hemopoietic 	 hemopoietic
# hemorrhagic 	 hemorrhagic
# hemostat 	 hemostat
# hemostatic 	 hemostatic
# hepatocarcinogenic 	 hepatocarcinogenic
# hepatomagenic 	 hepatomagenic
# hepatomegalic 	 hepatomegalic
# hepatoprotective 	 hepatoprotective
# hepatoregenerative 	 hepatoregenerative
# hepatotonic 	 hepatotonic
# hepatotoxic 	 hepatotoxic
# hepatotropic 	 hepatotropic
# herbicide 	 herbicide
# herbistat 	 herbistat
# herpetifuge 	 herpetifuge
# HIF-1alpha inhibitor 	 hif alpha inhibitor
# hirudicide 	 hirudicide
# histamine inhibitor 	 histamine inhibitor
# histaminic 	 histaminic
# histidine-kinase inhibitor 	 histidine kinase inhibitor
# HIV-reverse-transcriptase inhibitor 	 hiv reverse transcriptase inhibitor
# hormonal 	 hormonal
# hormone 	 hormone
# humectant 	 humectant
# hyaluronidase inhibitor 	 hyaluronidase inhibitor
# hydrocholerectic 	 hydrocholerectic
# hydrogen-peroxide inhibitor 	 hydrogen peroxide inhibitor
# hydroperoxidase inhibitor 	 hydroperoxidase inhibitor
# hypercalcuric 	 hypercalcuric
# hypercholesterolemic 	 hypercholesterolemic
# hyperemic 	 hyperemic
# hyperglycemic 	 hyperglycemic
# hyperpyrexic 	 hyperpyrexic
# hypertensive 	 hypertensive
# hyperthermic 	 hyperthermic
# hyperthyroid 	 hyperthyroid
# hypertrichotic 	 hypertrichotic
# hyperuricemic 	 hyperuricemic
# hypnotic 	 hypnotic
# hypoammonemic 	 hypoammonemic
# hypoarginanemic 	 hypoarginanemic
# hypocalcemic 	 hypocalcemic
# hypocholesterolemic 	 hypocholesterolemic
# hypoglycemic 	 hypoglycemic
# hypokalemic 	 hypokalemic
# hypolipemic 	 hypolipemic
# hypolipidemic 	 hypolipidemic
# hypotensive 	 hypotensive
# hypothalmic depressant 	 hypothalmic depressant
# hypothermic 	 hypothermic
# hypotriglyceridemic 	 hypotriglyceridemic
# hypouricemic 	 hypouricemic
# ICAM-1 inhibitor 	 icam inhibitor
# I-kappa-B-alpha-phosphorylation inhibitor 	 i kappa b alpha phosphorylation inhibitor
# IKB-kinase inhibitor 	 ikb kinase inhibitor
# IKK inhibitor 	 ikk inhibitor
# ileorelaxant 	 ileorelaxant
# immunomodulator 	 immunomodulator
# immunostimulant 	 immunostimulant
# immunosuppressant 	 immunosuppressant
# inflammatory 	 inflammatory
# inhalant 	 inhalant
# iNOS inhibitor 	 inos inhibitor
# inotropic 	 inotropic
# insect attractant 	 insect attractant
# insect repellent 	 insect repellent
# insecticide 	 insecticide
# insectifuge 	 insectifuge
# Insectiphile 	 insectiphile
# insulin-sparing 	 insulin sparing
# insulinase inhibitor 	 insulinase inhibitor
# insulinic 	 insulinic
# insulinogenic 	 insulinogenic
# insulinotonic 	 insulinotonic
# interferon-synergist 	 interferon synergist
# interferonogenic 	 interferonogenic
# interleukin-1-alpha inhibitor 	 interleukin alpha inhibitor
# interleukin-6 inhibitor 	 interleukin inhibitor
# interleukin-6-mRNA inhibitor 	 interleukin mrna inhibitor
# intoxicant 	 intoxicant
# iodothyronine-deiodinase inhibitor 	 iodothyronine deiodinase inhibitor
# irritant 	 irritant
# isoptericide 	 isoptericide
# JNK inhibitor 	 jnk inhibitor
# juvabional 	 juvabional
# keratitigenic 	 keratitigenic
# keratolytic 	 keratolytic
# lachrymatory 	 lachrymatory
# lactagogue 	 lactagogue
# larvicide 	 larvicide
# larvistat 	 larvistat
# laxative 	 laxative
# LDL lytic 	 ldl lytic
# leptingenic 	 leptingenic
# leucocyte depressant 	 leucocyte depressant
# leucocytogenic 	 leucocytogenic
# leukotriene inhibitor 	 leukotriene inhibitor
# libidolytic 	 libidolytic
# lipase inducer 	 lipase inducer
# lipase inhibitor 	 lipase inhibitor
# lipolytic 	 lipolytic
# lipotropic 	 lipotropic
# lipoxygenase-1 inhibitor 	 lipoxygenase inhibitor
# lipoxygenase inhibitor 	 lipoxygenase inhibitor
# lithogenic 	 lithogenic
# litholytic 	 litholytic
# lubricant 	 lubricant
# lupus generating 	 lupus generating
# lyase inhibitor 	 lyase inhibitor
# lymphocytogenic 	 lymphocytogenic
# lymphokinetic 	 lymphokinetic
# lypolytic 	 lypolytic
# maltase-promoter 	 maltase promoter
# monoamine-oxidase-A inhibitor 	 monoamine oxidase a inhibitor
# monoamine-oxidase-B inhibitor 	 monoamine oxidase b inhibitor
# monoamine-oxidase inhibitor 	 monoamine oxidase inhibitor
# mitogen-activated-protein-kinase inhibitor 	 mitogen activated protein kinase inhibitor
# mast-cell stabilizer 	 mast cell stabilizer
# mastogenic 	 mastogenic
# multidrug resistance inhibitor 	 multidrug resistance inhibitor
# melaninogenic 	 melaninogenic
# melatoninogenic 	 melatoninogenic
# membranolytic 	 membranolytic
# memorigenic 	 memorigenic
# memory enhancer 	 memory enhancer
# memranolytic 	 memranolytic
# metal chelator 	 metal chelator
# metalloproteinase inhibitor 	 metalloproteinase inhibitor
# metastatic 	 metastatic
# methyl-guanidine inhibitor 	 methyl guanidine inhibitor
# microvasculokinetic 	 microvasculokinetic
# mineral-corticoid 	 mineral corticoid
# miotic 	 miotic
# mitogen 	 mitogen
# mitogenic 	 mitogenic
# mitotic 	 mitotic
# matrix-metalloproteinase-2 inhibitor 	 matrix metalloproteinase inhibitor
# matrix-metalloproteinase-7 inhibitor 	 matrix metalloproteinase inhibitor
# matrix-metalloproteinase-9 inhibitor 	 matrix metalloproteinase inhibitor
# molluscicide 	 molluscicide
# monoamine precursor 	 monoamine precursor
# monoaminergic 	 monoaminergic
# mosquitocide 	 mosquitocide
# mosquitofuge 	 mosquitofuge
# motor depressant 	 motor depressant
# motor stimulant 	 motor stimulant
# mucogenic 	 mucogenic
# mucokinetic 	 mucokinetic
# mucolytic 	 mucolytic
# mucotropic 	 mucotropic
# musculotropic 	 musculotropic
# mutagenic 	 mutagenic
# mycobactericide 	 mycobactericide
# mycoplasmicide 	 mycoplasmicide
# mycoplasmistat 	 mycoplasmistat
# mydriatic 	 mydriatic
# myocardiotonic 	 myocardiotonic
# myocontractant 	 myocontractant
# myopic 	 myopic
# myoprotective 	 myoprotective
# myorelaxant 	 myorelaxant
# myostimulant 	 myostimulant
# myotonic 	 myotonic
# NADPH-oxidase inhibitor 	 nadph oxidase inhibitor
# NADH-ubiquinone-oxidoreductase inhibitor 	 nadh ubiquinone oxidoreductase inhibitor
# narcotic 	 narcotic
# natriuretic 	 natriuretic
# nematicide 	 nematicide
# nematiovistat 	 nematiovistat
# nematistat 	 nematistat
# nemativoistat 	 nemativoistat
# neoplastic 	 neoplastic
# neutral-endopeptidase inhibitor 	 neutral endopeptidase inhibitor
# nephroprotective 	 nephroprotective
# nephrotoxic 	 nephrotoxic
# neurodepressant 	 neurodepressant
# neuroexcitant 	 neuroexcitant
# neurogenic 	 neurogenic
# neuro inhibitor 	 neuro inhibitor
# neuroleptic 	 neuroleptic
# neurolytic 	 neurolytic
# neuromyostimulant 	 neuromyostimulant
# neuroparalytic 	 neuroparalytic
# neuropathogenic 	 neuropathogenic
# neuroprotective 	 neuroprotective
# neurostimulant 	 neurostimulant
# neurotoxic 	 neurotoxic
# neurotransmitter 	 neurotransmitter
# neurotropic 	 neurotropic
# NF-kappa-B inducer 	 nf kappa b inducer
# NF-kappa-B inhibitor 	 nf kappa b inhibitor
# nicotinic 	 nicotinic
# nitric-oxide-genic 	 nitric oxide genic
# nitric-oxide inhibitor 	 nitric oxide inhibitor
# nitric-oxide scavenger 	 nitric oxide scavenger
# nitric-oxide-synthase inhibitor 	 nitric oxide synthase inhibitor
# nociceptive 	 nociceptive
# nodulation signal 	 nodulation signal
# occuloirritant 	 occuloirritant
# odontolytic 	 odontolytic
# ophthalmic antialkali 	 ophthalmic antialkali
# ornithine-decarboxylase inhibitor 	 ornithine decarboxylase inhibitor
# osmoregulator 	 osmoregulator
# osteoblastogenic 	 osteoblastogenic
# osteogenic 	 osteogenic
# osteolytic 	 osteolytic
# ovicide 	 ovicide
# oviposition stimulant 	 oviposition stimulant
# ovulant 	 ovulant
# oxidant 	 oxidant
# oxidase inhibitor 	 oxidase inhibitor
# oxytocic 	 oxytocic
# oxyuricide 	 oxyuricide
# ozone scavenger 	 ozone scavenger
# cytochrome-P21 inducer 	 cytochrome p inducer
# cytochrome-P450-1A inducer 	 cytochrome p a inducer
# cytochrome-P450-2B inducer 	 cytochrome p b inducer
# cytochrome-P450-2B1 inhibitor 	 cytochrome p b inhibitor
# platelet aggregation factor inhibitor 	 platelet aggregation factor inhibitor
# pancreatogenic 	 pancreatogenic
# pancreatoxic 	 pancreatoxic
# papain inhibitor 	 papain inhibitor
# paralytic 	 paralytic
# paramecicide 	 paramecicide
# parasiticide 	 parasiticide
# parasympathicomimetic 	 parasympathicomimetic
# parasympathomimetic 	 parasympathomimetic
# pectinolytic 	 pectinolytic
# pediculicide 	 pediculicide
# pemphigenic 	 pemphigenic
# percutaneostimulant 	 percutaneostimulant
# perfume 	 perfume
# perfumery 	 perfumery
# peristaltic 	 peristaltic
# peroxidase inhibitor 	 peroxidase inhibitor
# peroxynitrite scavenger 	 peroxynitrite scavenger
# pesticide 	 pesticide
# prostaglandin-E2 inhibitor 	 prostaglandin e inhibitor
# phagocytotic 	 phagocytotic
# pheromonal 	 pheromonal
# pheromone 	 pheromone
# phosphodiesterase inhibitor 	 phosphodiesterase inhibitor
# phospholipase-A2 inhibitor 	 phospholipase a inhibitor
# phospholipase inhibitor 	 phospholipase inhibitor
# photoactive 	 photoactive
# photocarcinogenic 	 photocarcinogenic
# photodermatitigenic 	 photodermatitigenic
# photosensitizer 	 photosensitizer
# phototoxic 	 phototoxic
# phytoalexin 	 phytoalexin
# phytohormonal 	 phytohormonal
# phytohormone 	 phytohormone
# phytotoxic 	 phytotoxic
# pigment 	 pigment
# piscicide 	 piscicide
# pituitary sensitizer 	 pituitary sensitizer
# pituitary stimulant 	 pituitary stimulant
# protein kinase C inhibitor 	 protein kinase c inhibitor
# protein kinase D inhibitor 	 protein kinase d inhibitor
# plasmodicide 	 plasmodicide
# podagragenic 	 podagragenic
# poison 	 poison
# polyamine synthesis inhibitor 	 polyamine synthesis inhibitor
# potassium-sparing 	 potassium sparing
# poultice 	 poultice
# peroxisome proliferator activated receptor gamma antagonist 	 peroxisome proliferator activated receptor gamma antagonist
# prebiotic 	 prebiotic
# preservative 	 preservative
# pressor 	 pressor
# provitamin A 	 provitamin a
# priapistic 	 priapistic
# probiotic 	 probiotic
# probiotigenic 	 probiotigenic
# progestational 	 progestational
# progesteronigenic 	 progesteronigenic
# pro HLDL 	 pro hldl
# prolactinogenic 	 prolactinogenic
# proliferant 	 proliferant
# prooxidant 	 prooxidant
# propecic 	 propecic
# prostaglandigenic 	 prostaglandigenic
# prostaglandin inhibitor 	 prostaglandin inhibitor
# prostaglandin secretor 	 prostaglandin secretor
# prostaglandin sparer 	 prostaglandin sparer
# prostaglandin synthesis inhibitor 	 prostaglandin synthesis inhibitor
# prostaglandin-synthetase inhibitor 	 prostaglandin synthetase inhibitor
# prostatitigenic 	 prostatitigenic
# prosticide 	 prosticide
# protease inhibitor 	 protease inhibitor
# protein kinase inhibitor 	 protein kinase inhibitor
# proteinase inhibitor 	 proteinase inhibitor
# proteolytic 	 proteolytic
# protisticide 	 protisticide
# pruritogenic 	 pruritogenic
# psychoactive 	 psychoactive
# psychotomimetic 	 psychotomimetic
# psychotropic 	 psychotropic
# protein-tyrosine-kinase inhibitor 	 protein tyrosine kinase inhibitor
# pulifuge 	 pulifuge
# pulmonoprotective 	 pulmonoprotective
# pulmonotoxic 	 pulmonotoxic
# purgative 	 purgative
# pyrogenic 	 pyrogenic
# quinone-reductase inducer 	 quinone reductase inducer
# quinone-reductase inhibitor 	 quinone reductase inhibitor
# radioprotective 	 radioprotective
# refrigerant 	 refrigerant
# renoirritant 	 renoirritant
# renotoxic 	 renotoxic
# repellent 	 repellent
# RES-activator 	 res activator
# respiradepressant 	 respiradepressant
# respira inhibitor 	 respira inhibitor
# respiraparalytic 	 respiraparalytic
# respirasensitizer 	 respirasensitizer
# respirastimulant 	 respirastimulant
# respirodepressant 	 respirodepressant
# respiroinhibitor 	 respiroinhibitor
# respirostimulant 	 respirostimulant
# respirotoxic 	 respirotoxic
# retinoprotectant 	 retinoprotectant
# reverse transcriptase inhibitor 	 reverse transcriptase inhibitor
# ribosome inactivator 	 ribosome inactivator
# RNA-genic 	 rna genic
# RNA inhibitor 	 rna inhibitor
# roborant 	 roborant
# rodenticide 	 rodenticide
# rubefacient 	 rubefacient
# scabicide 	 scabicide
# schistosomicide 	 schistosomicide
# schizophrenigenic 	 schizophrenigenic
# sclerosant 	 sclerosant
# scolicide 	 scolicide
# seasoning 	 seasoning
# secretogogue 	 secretogogue
# secretolytic 	 secretolytic
# secretomotor 	 secretomotor
# sedative 	 sedative
# sequestrant 	 sequestrant
# serotonin inhibitor 	 serotonin inhibitor
# serotoninergic 	 serotoninergic
# sialogogue 	 sialogogue
# soap 	 soap
# sodium-sparing 	 sodium sparing
# soporific 	 soporific
# sortase-A inhibitor 	 sortase a inhibitor
# spasmogenic 	 spasmogenic
# spasmolytic 	 spasmolytic
# spermicide 	 spermicide
# spermigenic 	 spermigenic
# spice 	 spice
# spinoconvulsant 	 spinoconvulsant
# sprout inhibitor 	 sprout inhibitor
# squalene-monooxygenase inhibitor 	 squalene monooxygenase inhibitor
# sternutatory 	 sternutatory
# stimulant 	 stimulant
# stomachic 	 stomachic
# styptic 	 styptic
# succinate-dehydrogenase inhibitor 	 succinate dehydrogenase inhibitor
# succinic-dehydrogenase inhibitor 	 succinic dehydrogenase inhibitor
# succinoxidase inhibitor 	 succinoxidase inhibitor
# sucrase promoter 	 sucrase promoter
# sudorific 	 sudorific
# sunscreen 	 sunscreen
# suppository 	 suppository
# suppurative 	 suppurative
# surfactant 	 surfactant
# sweetener 	 sweetener
# sympathomimetic 	 sympathomimetic
# synergist 	 synergist
# systolic depressant 	 systolic depressant
# tachycardic 	 tachycardic
# taenicide 	 taenicide
# teratogenic 	 teratogenic
# teratologic 	 teratologic
# termiticide 	 termiticide
# termitifuge 	 termitifuge
# testosterogenic 	 testosterogenic
# testosterone-hydroxylase inducer 	 testosterone hydroxylase inducer
# testosterone inducer 	 testosterone inducer
# testosteronigenic 	 testosteronigenic
# thermogenic 	 thermogenic
# thymoprotective 	 thymoprotective
# thyroid-peroxidase inhibitor 	 thyroid peroxidase inhibitor
# thyrostimulant 	 thyrostimulant
# thyrotropic 	 thyrotropic
# tineacide 	 tineacide
# tinnitigenic 	 tinnitigenic
# tissue thromboplastin inhibitor 	 tissue thromboplastin inhibitor
# TNF-alpha inhibitor 	 tnf alpha inhibitor
# TNF inhibitor 	 tnf inhibitor
# tonic 	 tonic
# topoisomerase-II inhibitor 	 topoisomerase ii inhibitor
# topoisomerase-I antagonist 	 topoisomerase i antagonist
# topoisomerase-I inhibitor 	 topoisomerase i inhibitor
# topoisomerase-II poison 	 topoisomerase ii poison
# popoisomerase inhibitor 	 popoisomerase inhibitor
# toxic 	 toxic
# tracheorelaxant 	 tracheorelaxant
# tranquilizer 	 tranquilizer
# transdermal 	 transdermal
# trematodicide 	 trematodicide
# tremorigenic 	 tremorigenic
# tremorilytic 	 tremorilytic
# tremorogenic 	 tremorogenic
# trichomonicide 	 trichomonicide
# trichomonistat 	 trichomonistat
# trichuricide 	 trichuricide
# triglycerigenic 	 triglycerigenic
# triglycerolytic 	 triglycerolytic
# trypanocide 	 trypanocide
# trypanosomastat 	 trypanosomastat
# trypsin enhancer 	 trypsin enhancer
# tumor promoter 	 tumor promoter
# tumorigenic 	 tumorigenic
# tyrosinase inhibitor 	 tyrosinase inhibitor
# tyrosine-kinase inhibitor 	 tyrosine kinase inhibitor
# ubiquiot 	 ubiquiot
# ulcerogenic 	 ulcerogenic
# urate-solvent 	 urate solvent
# urease inhibitor 	 urease inhibitor
# uricogenic 	 uricogenic
# uricosuric 	 uricosuric
# urinary acidulant 	 urinary acidulant
# urinary antiseptic 	 urinary antiseptic
# urine acidifier 	 urine acidifier
# urine deodorant 	 urine deodorant
# urokinase inhibitor 	 urokinase inhibitor
# uteroactive 	 uteroactive
# utero relaxant 	 utero relaxant
# uteros sedative 	 uteros sedative
# utero tonic 	 utero tonic
# utero trophic 	 utero trophic
# UV-screen 	 uv screen
# VAM simulant 	 vam simulant
# VAM stimulant 	 vam stimulant
# varroacide 	 varroacide
# vasoactive 	 vasoactive
# vasoconstrictor 	 vasoconstrictor
# vasodilator 	 vasodilator
# vasomotor stimulant 	 vasomotor stimulant
# vasopressor 	 vasopressor
# vasoprotective 	 vasoprotective
# vasorelaxant 	 vasorelaxant
# VEGF inhibitor 	 vegf inhibitor
# venoprotective 	 venoprotective
# venotonic 	 venotonic
# vermicide 	 vermicide
# vermifuge 	 vermifuge
# verrucolytic 	 verrucolytic
# vertigenic 	 vertigenic
# vertiginous 	 vertiginous
# vesicant 	 vesicant
# vibriocide 	 vibriocide
# viristat 	 viristat
# vitamin-A activity 	 vitamin a activity
# vulnerary 	 vulnerary
# xanthine oxidase inhibitor 	 xanthine oxidase inhibitor
# inhibitor 	 inhibitor
# prostaglandin antagonist 	 prostaglandin antagonist
# platelet aggregation inhibitor 	 platelet aggregation inhibitor
# EC 3.2.1.18 (exo-alpha-sialidase) inhibitor 	 ec exo alpha sialidase inhibitor

# %% [markdown]
# # Crear un diccionario de vectores embebidos para cada nombre

# %%
embedded_names = dict()
rare_words = list()

# Definición de la lista que almacenará los nombres
for text in df['name']:
    # Acondicionando el texto
    preprocessed_text = preprocessing_text(text)
    
    # Separando por palabras
    preprocessed_text = preprocessed_text.split()
    
    # Definición de la list de vectores embebidos
    embedded_vects_i = list()
    
    for i in preprocessed_text:
        if len(i) > 2:
            # Buscar el vector embebido
            embedded_i = embeddings_index.get(i)
            if embedded_i is not None:
                embedded_vects_i.append(embedded_i)
            else:
                rare_words.append(i)
                
    if embedded_vects_i:
        embedded_names[text] = embedded_vects_i
    else:
        print(f'Nombre {text} no tiene vectores embebidos')
# Out:
# Nombre (-)-chronotropic no tiene vectores embebidos
# Nombre acantholytic no tiene vectores embebidos
# Nombre acaricide no tiene vectores embebidos
# Nombre acarifuge no tiene vectores embebidos
# Nombre acetylcholinergic no tiene vectores embebidos
# Nombre acidifier no tiene vectores embebidos
# Nombre acidulant no tiene vectores embebidos
# Nombre acnegenic no tiene vectores embebidos
# Nombre adaptogenic no tiene vectores embebidos
# Nombre aedifuge no tiene vectores embebidos
# Nombre aggregant no tiene vectores embebidos
# Nombre albuminurigenic no tiene vectores embebidos
# Nombre allelochemic no tiene vectores embebidos
# Nombre amblyopic no tiene vectores embebidos
# Nombre amebicide no tiene vectores embebidos
# Nombre amnesigenic no tiene vectores embebidos
# Nombre amphetaminagenic no tiene vectores embebidos
# Nombre amphiestrogenic no tiene vectores embebidos
# Nombre amphiglycemic no tiene vectores embebidos
# Nombre amphitensive no tiene vectores embebidos
# Nombre analeptic no tiene vectores embebidos
# Nombre anaphrodisiac no tiene vectores embebidos
# Nombre ancylostomicide no tiene vectores embebidos
# Nombre anemiagenic no tiene vectores embebidos
# Nombre anhydrotic no tiene vectores embebidos
# Nombre ankylostomacide no tiene vectores embebidos
# Nombre aphicide no tiene vectores embebidos
# Nombre aphidifuge no tiene vectores embebidos
# Nombre apifuge no tiene vectores embebidos
# Nombre arrhythmigenic no tiene vectores embebidos
# Nombre artemicide no tiene vectores embebidos
# Nombre arteriodilator no tiene vectores embebidos
# Nombre ascaricide no tiene vectores embebidos
# Nombre ataractic no tiene vectores embebidos
# Nombre ataxigenic no tiene vectores embebidos
# Nombre atherogenic no tiene vectores embebidos
# Nombre attifuge no tiene vectores embebidos
# Nombre autotoxic no tiene vectores embebidos
# Nombre avicide no tiene vectores embebidos
# Nombre avifuge no tiene vectores embebidos
# Nombre bactericide no tiene vectores embebidos
# Nombre bacteriophagicide no tiene vectores embebidos
# Nombre bacteristat no tiene vectores embebidos
# Nombre barbituate-synergist no tiene vectores embebidos
# Nombre bifidogenic no tiene vectores embebidos
# Nombre bilirubinolytic no tiene vectores embebidos
# Nombre bradycardiac no tiene vectores embebidos
# Nombre bradycardic no tiene vectores embebidos
# Nombre bronchoconstrictor no tiene vectores embebidos
# Nombre bronchomucolytic no tiene vectores embebidos
# Nombre bronchomucotropic no tiene vectores embebidos
# Nombre bronchoprotectant no tiene vectores embebidos
# Nombre bronchorrheic no tiene vectores embebidos
# Nombre bronchosedative no tiene vectores embebidos
# Nombre bronchospasmolytic no tiene vectores embebidos
# Nombre bronchostimulant no tiene vectores embebidos
# Nombre bruchifuge no tiene vectores embebidos
# Nombre bruchiphobe no tiene vectores embebidos
# Nombre bufocide no tiene vectores embebidos
# Nombre candidicide no tiene vectores embebidos
# Nombre candidistat no tiene vectores embebidos
# Nombre capillarifortificant no tiene vectores embebidos
# Nombre capillarigenic no tiene vectores embebidos
# Nombre capillariprotective no tiene vectores embebidos
# Nombre capillaritonic no tiene vectores embebidos
# Nombre carcinostatic no tiene vectores embebidos
# Nombre cardioactive no tiene vectores embebidos
# Nombre cardiodepressant no tiene vectores embebidos
# Nombre cardiomyopathogenic no tiene vectores embebidos
# Nombre cardioparalytic no tiene vectores embebidos
# Nombre cardiosedative no tiene vectores embebidos
# Nombre cardiotonic no tiene vectores embebidos
# Nombre cardiotoxic no tiene vectores embebidos
# Nombre carminative no tiene vectores embebidos
# Nombre cataractagenic no tiene vectores embebidos
# Nombre catecholaminogenic no tiene vectores embebidos
# Nombre cerebrodepressant no tiene vectores embebidos
# Nombre cerebrophilic no tiene vectores embebidos
# Nombre cerebroprotective no tiene vectores embebidos
# Nombre cerebrostimulant no tiene vectores embebidos
# Nombre cerebrotonic no tiene vectores embebidos
# Nombre cerebrotoxic no tiene vectores embebidos
# Nombre cerumenolytic no tiene vectores embebidos
# Nombre cestodicide no tiene vectores embebidos
# Nombre chelator no tiene vectores embebidos
# Nombre chemopreventive no tiene vectores embebidos
# Nombre chitinolytic no tiene vectores embebidos
# Nombre chitosanolytic no tiene vectores embebidos
# Nombre cholagogue no tiene vectores embebidos
# Nombre choleretic no tiene vectores embebidos
# Nombre cholesterolytic no tiene vectores embebidos
# Nombre chronotropic no tiene vectores embebidos
# Nombre cicatrizant no tiene vectores embebidos
# Nombre ciliotoxic no tiene vectores embebidos
# Nombre circulotonic no tiene vectores embebidos
# Nombre clastogenic no tiene vectores embebidos
# Nombre coleopterifuge no tiene vectores embebidos
# Nombre coleoptophile no tiene vectores embebidos
# Nombre collagenic no tiene vectores embebidos
# Nombre collyrium no tiene vectores embebidos
# Nombre comedogenic no tiene vectores embebidos
# Nombre comedolytic no tiene vectores embebidos
# Nombre congestant no tiene vectores embebidos
# Nombre coronarydilator no tiene vectores embebidos
# Nombre corticosterogenic no tiene vectores embebidos
# Nombre counterirritant no tiene vectores embebidos
# Nombre crustacicide no tiene vectores embebidos
# Nombre culicide no tiene vectores embebidos
# Nombre cytoprotective no tiene vectores embebidos
# Nombre cytostatic no tiene vectores embebidos
# Nombre decalcifier no tiene vectores embebidos
# Nombre degranulant no tiene vectores embebidos
# Nombre deliriant no tiene vectores embebidos
# Nombre demulcent no tiene vectores embebidos
# Nombre dentifrice no tiene vectores embebidos
# Nombre depigmentor no tiene vectores embebidos
# Nombre dermatitigenic no tiene vectores embebidos
# Nombre desmutagenic no tiene vectores embebidos
# Nombre detoxicant no tiene vectores embebidos
# Nombre diaphoretic no tiene vectores embebidos
# Nombre copaminigenic no tiene vectores embebidos
# Nombre ecbolic no tiene vectores embebidos
# Nombre ectoparasiticide no tiene vectores embebidos
# Nombre edemagenic no tiene vectores embebidos
# Nombre embryotoxic no tiene vectores embebidos
# Nombre emmenagogue no tiene vectores embebidos
# Nombre encephalopathic no tiene vectores embebidos
# Nombre endocrinactive no tiene vectores embebidos
# Nombre endorphinogenic no tiene vectores embebidos
# Nombre enterocontractant no tiene vectores embebidos
# Nombre enterorelaxant no tiene vectores embebidos
# Nombre enterotoxic no tiene vectores embebidos
# Nombre epileptigenic no tiene vectores embebidos
# Nombre epinephrininergic no tiene vectores embebidos
# Nombre ergogenic no tiene vectores embebidos
# Nombre erythrocytogenic no tiene vectores embebidos
# Nombre erythrocytolytic no tiene vectores embebidos
# Nombre ethanolytic no tiene vectores embebidos
# Nombre euphoriant no tiene vectores embebidos
# Nombre febrifuge no tiene vectores embebidos
# Nombre fetotoxic no tiene vectores embebidos
# Nombre fibrinolytic no tiene vectores embebidos
# Nombre flatugenic no tiene vectores embebidos
# Nombre fungiphilic no tiene vectores embebidos
# Nombre fungistat no tiene vectores embebidos
# Nombre fungitoxic no tiene vectores embebidos
# Nombre gastroirritant no tiene vectores embebidos
# Nombre gastroprotective no tiene vectores embebidos
# Nombre gastrosedative no tiene vectores embebidos
# Nombre gastrostimulant no tiene vectores embebidos
# Nombre glaucomagenic no tiene vectores embebidos
# Nombre glucogonogenic no tiene vectores embebidos
# Nombre glutathionalytic no tiene vectores embebidos
# Nombre glutathionergic no tiene vectores embebidos
# Nombre glutathionigenic no tiene vectores embebidos
# Nombre goitrogenic no tiene vectores embebidos
# Nombre gonadotrophic no tiene vectores embebidos
# Nombre gonadotropic no tiene vectores embebidos
# Nombre Gram(+)icide no tiene vectores embebidos
# Nombre hemopoietic no tiene vectores embebidos
# Nombre hemostat no tiene vectores embebidos
# Nombre hepatocarcinogenic no tiene vectores embebidos
# Nombre hepatomagenic no tiene vectores embebidos
# Nombre hepatomegalic no tiene vectores embebidos
# Nombre hepatoprotective no tiene vectores embebidos
# Nombre hepatoregenerative no tiene vectores embebidos
# Nombre hepatotonic no tiene vectores embebidos
# Nombre hepatotropic no tiene vectores embebidos
# Nombre herbistat no tiene vectores embebidos
# Nombre herpetifuge no tiene vectores embebidos
# Nombre hirudicide no tiene vectores embebidos
# Nombre histaminic no tiene vectores embebidos
# Nombre humectant no tiene vectores embebidos
# Nombre hydrocholerectic no tiene vectores embebidos
# Nombre hypercalcuric no tiene vectores embebidos
# Nombre hypercholesterolemic no tiene vectores embebidos
# Nombre hyperemic no tiene vectores embebidos
# Nombre hyperglycemic no tiene vectores embebidos
# Nombre hyperpyrexic no tiene vectores embebidos
# Nombre hyperthermic no tiene vectores embebidos
# Nombre hypertrichotic no tiene vectores embebidos
# Nombre hyperuricemic no tiene vectores embebidos
# Nombre hypoammonemic no tiene vectores embebidos
# Nombre hypoarginanemic no tiene vectores embebidos
# Nombre hypocalcemic no tiene vectores embebidos
# Nombre hypocholesterolemic no tiene vectores embebidos
# Nombre hypolipemic no tiene vectores embebidos
# Nombre hypolipidemic no tiene vectores embebidos
# Nombre hypotriglyceridemic no tiene vectores embebidos
# Nombre hypouricemic no tiene vectores embebidos
# Nombre ileorelaxant no tiene vectores embebidos
# Nombre immunostimulant no tiene vectores embebidos
# Nombre insectifuge no tiene vectores embebidos
# Nombre Insectiphile no tiene vectores embebidos
# Nombre insulinic no tiene vectores embebidos
# Nombre insulinogenic no tiene vectores embebidos
# Nombre insulinotonic no tiene vectores embebidos
# Nombre interferonogenic no tiene vectores embebidos
# Nombre isoptericide no tiene vectores embebidos
# Nombre juvabional no tiene vectores embebidos
# Nombre keratitigenic no tiene vectores embebidos
# Nombre keratolytic no tiene vectores embebidos
# Nombre lachrymatory no tiene vectores embebidos
# Nombre lactagogue no tiene vectores embebidos
# Nombre larvistat no tiene vectores embebidos
# Nombre leptingenic no tiene vectores embebidos
# Nombre leucocytogenic no tiene vectores embebidos
# Nombre libidolytic no tiene vectores embebidos
# Nombre lipolytic no tiene vectores embebidos
# Nombre lipotropic no tiene vectores embebidos
# Nombre lithogenic no tiene vectores embebidos
# Nombre litholytic no tiene vectores embebidos
# Nombre lymphocytogenic no tiene vectores embebidos
# Nombre lymphokinetic no tiene vectores embebidos
# Nombre lypolytic no tiene vectores embebidos
# Nombre mastogenic no tiene vectores embebidos
# Nombre melaninogenic no tiene vectores embebidos
# Nombre melatoninogenic no tiene vectores embebidos
# Nombre membranolytic no tiene vectores embebidos
# Nombre memorigenic no tiene vectores embebidos
# Nombre memranolytic no tiene vectores embebidos
# Nombre microvasculokinetic no tiene vectores embebidos
# Nombre miotic no tiene vectores embebidos
# Nombre molluscicide no tiene vectores embebidos
# Nombre monoaminergic no tiene vectores embebidos
# Nombre mosquitocide no tiene vectores embebidos
# Nombre mosquitofuge no tiene vectores embebidos
# Nombre mucogenic no tiene vectores embebidos
# Nombre mucokinetic no tiene vectores embebidos
# Nombre mucolytic no tiene vectores embebidos
# Nombre mucotropic no tiene vectores embebidos
# Nombre musculotropic no tiene vectores embebidos
# Nombre mycobactericide no tiene vectores embebidos
# Nombre mycoplasmicide no tiene vectores embebidos
# Nombre mycoplasmistat no tiene vectores embebidos
# Nombre mydriatic no tiene vectores embebidos
# Nombre myocardiotonic no tiene vectores embebidos
# Nombre myocontractant no tiene vectores embebidos
# Nombre myoprotective no tiene vectores embebidos
# Nombre myorelaxant no tiene vectores embebidos
# Nombre myostimulant no tiene vectores embebidos
# Nombre nematicide no tiene vectores embebidos
# Nombre nematiovistat no tiene vectores embebidos
# Nombre nematistat no tiene vectores embebidos
# Nombre nemativoistat no tiene vectores embebidos
# Nombre nephroprotective no tiene vectores embebidos
# Nombre nephrotoxic no tiene vectores embebidos
# Nombre neurodepressant no tiene vectores embebidos
# Nombre neuroexcitant no tiene vectores embebidos
# Nombre neurolytic no tiene vectores embebidos
# Nombre neuromyostimulant no tiene vectores embebidos
# Nombre neuroparalytic no tiene vectores embebidos
# Nombre neuropathogenic no tiene vectores embebidos
# Nombre neurostimulant no tiene vectores embebidos
# Nombre neurotropic no tiene vectores embebidos
# Nombre occuloirritant no tiene vectores embebidos
# Nombre odontolytic no tiene vectores embebidos
# Nombre osmoregulator no tiene vectores embebidos
# Nombre osteoblastogenic no tiene vectores embebidos
# Nombre osteolytic no tiene vectores embebidos
# Nombre ovicide no tiene vectores embebidos
# Nombre ovulant no tiene vectores embebidos
# Nombre oxytocic no tiene vectores embebidos
# Nombre oxyuricide no tiene vectores embebidos
# Nombre pancreatogenic no tiene vectores embebidos
# Nombre pancreatoxic no tiene vectores embebidos
# Nombre paramecicide no tiene vectores embebidos
# Nombre parasiticide no tiene vectores embebidos
# Nombre parasympathicomimetic no tiene vectores embebidos
# Nombre parasympathomimetic no tiene vectores embebidos
# Nombre pectinolytic no tiene vectores embebidos
# Nombre pediculicide no tiene vectores embebidos
# Nombre pemphigenic no tiene vectores embebidos
# Nombre percutaneostimulant no tiene vectores embebidos
# Nombre phagocytotic no tiene vectores embebidos
# Nombre pheromonal no tiene vectores embebidos
# Nombre photoactive no tiene vectores embebidos
# Nombre photocarcinogenic no tiene vectores embebidos
# Nombre photodermatitigenic no tiene vectores embebidos
# Nombre phototoxic no tiene vectores embebidos
# Nombre phytoalexin no tiene vectores embebidos
# Nombre phytohormonal no tiene vectores embebidos
# Nombre phytohormone no tiene vectores embebidos
# Nombre phytotoxic no tiene vectores embebidos
# Nombre piscicide no tiene vectores embebidos
# Nombre plasmodicide no tiene vectores embebidos
# Nombre podagragenic no tiene vectores embebidos
# Nombre provitamin A no tiene vectores embebidos
# Nombre priapistic no tiene vectores embebidos
# Nombre probiotigenic no tiene vectores embebidos
# Nombre progestational no tiene vectores embebidos
# Nombre progesteronigenic no tiene vectores embebidos
# Nombre prolactinogenic no tiene vectores embebidos
# Nombre proliferant no tiene vectores embebidos
# Nombre prooxidant no tiene vectores embebidos
# Nombre propecic no tiene vectores embebidos
# Nombre prostaglandigenic no tiene vectores embebidos
# Nombre prostatitigenic no tiene vectores embebidos
# Nombre prosticide no tiene vectores embebidos
# Nombre protisticide no tiene vectores embebidos
# Nombre pruritogenic no tiene vectores embebidos
# Nombre psychotomimetic no tiene vectores embebidos
# Nombre pulifuge no tiene vectores embebidos
# Nombre pulmonoprotective no tiene vectores embebidos
# Nombre pulmonotoxic no tiene vectores embebidos
# Nombre pyrogenic no tiene vectores embebidos
# Nombre radioprotective no tiene vectores embebidos
# Nombre renoirritant no tiene vectores embebidos
# Nombre renotoxic no tiene vectores embebidos
# Nombre respiradepressant no tiene vectores embebidos
# Nombre respiraparalytic no tiene vectores embebidos
# Nombre respirasensitizer no tiene vectores embebidos
# Nombre respirastimulant no tiene vectores embebidos
# Nombre respirodepressant no tiene vectores embebidos
# Nombre respiroinhibitor no tiene vectores embebidos
# Nombre respirostimulant no tiene vectores embebidos
# Nombre respirotoxic no tiene vectores embebidos
# Nombre retinoprotectant no tiene vectores embebidos
# Nombre roborant no tiene vectores embebidos
# Nombre rubefacient no tiene vectores embebidos
# Nombre scabicide no tiene vectores embebidos
# Nombre schistosomicide no tiene vectores embebidos
# Nombre schizophrenigenic no tiene vectores embebidos
# Nombre sclerosant no tiene vectores embebidos
# Nombre scolicide no tiene vectores embebidos
# Nombre secretogogue no tiene vectores embebidos
# Nombre secretolytic no tiene vectores embebidos
# Nombre secretomotor no tiene vectores embebidos
# Nombre sequestrant no tiene vectores embebidos
# Nombre serotoninergic no tiene vectores embebidos
# Nombre sialogogue no tiene vectores embebidos
# Nombre spasmogenic no tiene vectores embebidos
# Nombre spasmolytic no tiene vectores embebidos
# Nombre spermigenic no tiene vectores embebidos
# Nombre spinoconvulsant no tiene vectores embebidos
# Nombre sternutatory no tiene vectores embebidos
# Nombre stomachic no tiene vectores embebidos
# Nombre styptic no tiene vectores embebidos
# Nombre sudorific no tiene vectores embebidos
# Nombre suppurative no tiene vectores embebidos
# Nombre synergist no tiene vectores embebidos
# Nombre tachycardic no tiene vectores embebidos
# Nombre taenicide no tiene vectores embebidos
# Nombre teratologic no tiene vectores embebidos
# Nombre termiticide no tiene vectores embebidos
# Nombre termitifuge no tiene vectores embebidos
# Nombre testosterogenic no tiene vectores embebidos
# Nombre testosteronigenic no tiene vectores embebidos
# Nombre thymoprotective no tiene vectores embebidos
# Nombre thyrostimulant no tiene vectores embebidos
# Nombre thyrotropic no tiene vectores embebidos
# Nombre tineacide no tiene vectores embebidos
# Nombre tinnitigenic no tiene vectores embebidos
# Nombre tracheorelaxant no tiene vectores embebidos
# Nombre trematodicide no tiene vectores embebidos
# Nombre tremorigenic no tiene vectores embebidos
# Nombre tremorilytic no tiene vectores embebidos
# Nombre tremorogenic no tiene vectores embebidos
# Nombre trichomonicide no tiene vectores embebidos
# Nombre trichomonistat no tiene vectores embebidos
# Nombre trichuricide no tiene vectores embebidos
# Nombre triglycerigenic no tiene vectores embebidos
# Nombre triglycerolytic no tiene vectores embebidos
# Nombre trypanocide no tiene vectores embebidos
# Nombre trypanosomastat no tiene vectores embebidos
# Nombre tumorigenic no tiene vectores embebidos
# Nombre ubiquiot no tiene vectores embebidos
# Nombre ulcerogenic no tiene vectores embebidos
# Nombre uricogenic no tiene vectores embebidos
# Nombre uricosuric no tiene vectores embebidos
# Nombre uteroactive no tiene vectores embebidos
# Nombre varroacide no tiene vectores embebidos
# Nombre vasopressor no tiene vectores embebidos
# Nombre vasoprotective no tiene vectores embebidos
# Nombre vasorelaxant no tiene vectores embebidos
# Nombre venoprotective no tiene vectores embebidos
# Nombre venotonic no tiene vectores embebidos
# Nombre vermicide no tiene vectores embebidos
# Nombre vermifuge no tiene vectores embebidos
# Nombre verrucolytic no tiene vectores embebidos
# Nombre vertigenic no tiene vectores embebidos
# Nombre vesicant no tiene vectores embebidos
# Nombre vibriocide no tiene vectores embebidos
# Nombre viristat no tiene vectores embebidos
# Nombre vulnerary no tiene vectores embebidos

# %% [markdown]
# # Obtener vectores representativos por concepto

# %%
key_list = list()
embedded_main_names = list() 

for key in embedded_names.keys():
    repr_vect = np.array(embedded_names[key]).mean(axis=0)
    embedded_main_names.append(repr_vect)
    key_list.append(key)
    
# Transformando a array
embedded_main_names = np.array(embedded_main_names)
embedded_main_names.shape
# Out:
# (1050, 100)

# %% [markdown]
# # Definición de funciones alimenticias objetivo

# %%
def find_Nprox_concepts(concept, embedding_matrix, index2word, N_words, 
                        metric='euclidean'):
    # Definición del vector de embedding
    embedded_concept = embeddings_index.get(concept)
    
    # Si no se encuentra el concepto, se termina la ejecución
    if embedded_concept is None: 
        print(f'Concept {concept} not found.')
        return
    
    if metric == 'euclidean':
        # Diferencia cuadrática
        dif_metric = np.sum((embedding_matrix - embedded_concept) ** 2, axis=1)
        reverse_sort = False

    elif metric == 'cosine':
        # Similaridad coseno
        dif_metric = (cosine_similarity(embedding_matrix, embedded_concept)) 
        reverse_sort = True
    
    else:
        raise Exception('Parámetro "metric" no válido. Intente nuevamente.')
    
    # Etiquetando posición
    pos_dif = [(i, delta) for i, delta in enumerate(dif_metric)]
    
    # Ordenando
    pos_dif.sort(key=lambda x: x[1], reverse=reverse_sort)
    
    # Obtener la salida
    if metric == 'euclidean':
        proximate_concepts = [(index2word[i[0]], np.sqrt(i[1])) 
                               for i in pos_dif[1:1+N_words]]
    
    elif metric == 'cosine':
        proximate_concepts = [(index2word[i[0]], i[1] * 100) 
                               for i in pos_dif[1:1+N_words]]

    return proximate_concepts


def find_concepts_by_radius(concept, embedding_matrix, index2word, radius):
    # Definición del vector de embedding
    embedded_concept = embeddings_index.get(concept)
    
    # Si no se encuentra el concepto, se termina la ejecución
    if embedded_concept is None: 
        print(f'Concept {concept} not found.')
        return

    # Diferencia cuadrática
    dif_metric = np.sqrt(np.sum((embedding_matrix - embedded_concept) ** 2, axis=1))
    
    # Etiquetando posición y filtrando solo las que cumplan con el criterio del radio
    pos_dif = [(i, delta) for i, delta in enumerate(dif_metric)
               if delta <= radius]
    
    # Ordenando
    pos_dif.sort(key=lambda x: x[1])

    # Obtener la salida
    proximate_concepts = [(index2word[i[0]], i[1]) for i in pos_dif]

    return proximate_concepts

# %%
# Definición de los conceptos objetivos a revisar en el embedding
objective_concepts = ['digestion', 'antioxidant', 'nutrition',  'vitamins', 
                      'nutrients', 'minerals', 'energetic', 'energy']

for concept in objective_concepts:
    result = find_Nprox_concepts(concept, embedding_matrix=embedded_main_names, 
                                 index2word=key_list, N_words=20, 
                                 metric='cosine')
    
#     result = find_concepts_by_radius(concept, embedding_matrix=embeddings_matrix, 
#                                      index2word=idx2word, radius=5)
    
    print(concept)
    display(result)
# Out:
# 1050
# digestion
# [('insulin-sparing', 54.072123765945435),
#  ('choline-sparing', 52.624547481536865),
#  ('calcium-sparing', 52.448850870132446),
#  ('collagen-sparing', 49.449992179870605),
#  ('proteolytic', 49.178722500801086),
#  ('heme-sparing', 49.05781447887421),
#  ('trypsin enhancer', 46.5628981590271),
#  ('dopamine-adenylate-cyclase inhibitor', 46.34324014186859),
#  ('potassium-sparing', 46.31853401660919),
#  ('angiotensin converting enzyme inhibitor', 46.15551233291626),
#  ('thyroid-peroxidase inhibitor', 45.89885473251343),
#  ('5-hydroxyeicosatetraenoic-acid inhibitor', 45.3142374753952),
#  ('8-hydroxyeicosatetraenoic-acid inhibitor', 45.3142374753952),
#  ('cytochrome-p450 inducer', 45.15664279460907),
#  ('cytochrome-p488 inducer', 45.15664279460907),
#  ('cytochrome-P21 inducer', 45.15664279460907),
#  ('cytochrome-P450-1A inducer', 45.15664279460907),
#  ('cytochrome-P450-2B inducer', 45.15664279460907),
#  ('urinary antiseptic', 44.86902952194214),
#  ('sodium-sparing', 44.7851836681366)]
# 1050
# antioxidant
# [('vitamin-A activity', 59.71183776855469),
#  ('lipase inhibitor', 59.33906435966492),
#  ('thyroid-peroxidase inhibitor', 59.17971730232239),
#  ('TNF inhibitor', 58.8148832321167),
#  ('aryl-hydrocarbon-hydroxylase inhibitor', 58.10437798500061),
#  ('estrogen agonist', 57.83643126487732),
#  ('arylamine-N-acetyltransferase inhibitor', 56.27970099449158),
#  ('peroxidase inhibitor', 56.04261755943298),
#  ('antitumor', 55.810028314590454),
#  ('prostaglandin-E2 inhibitor', 55.529069900512695),
#  ('prostaglandin inhibitor', 55.529069900512695),
#  ('estrogenic', 55.29184341430664),
#  ('platelet aggregation inhibitor', 55.205899477005005),
#  ('protein kinase C inhibitor', 55.070918798446655),
#  ('protein kinase D inhibitor', 55.070918798446655),
#  ('protein kinase inhibitor', 55.070918798446655),
#  ('activator-protein-1 inhibitor', 55.06500005722046),
#  ('interleukin-6 inhibitor', 54.894739389419556),
#  ('protein-tyrosine-kinase inhibitor', 54.82253432273865),
#  ('platelet aggregation factor inhibitor', 54.54651117324829)]
# 1050
# nutrition
# [('asthma preventive', 54.996609687805176),
#  ('cancer preventive', 54.4893741607666),
#  ('vitamin-A activity', 49.89945888519287),
#  ('anti obesity', 46.63013517856598),
#  ('digestive', 44.99504566192627),
#  ('diagnostic', 43.874791264534),
#  ('cold preventive', 43.81129741668701),
#  ('essential', 43.39466691017151),
#  ('anti reproductive', 42.708319425582886),
#  ('anti metabolic', 40.96790850162506),
#  ('anti glucose-tolerance-factor', 40.55205583572388),
#  ('contraceptive', 39.57436382770538),
#  ('pesticide', 38.7987494468689),
#  ('fistula preventive', 37.2603714466095),
#  ('hormone', 36.21225357055664),
#  ('antibiotic', 35.92291176319122),
#  ('hormonal', 34.808188676834106),
#  ('anti infertility', 34.651872515678406),
#  ('anti fertility', 34.42915380001068),
#  ('anti AIDS', 34.23459529876709)]
# 1050
# vitamins
# [('calcium-sparing', 61.17306351661682),
#  ('antioxidant', 58.32422971725464),
#  ('5-hydroxyeicosatetraenoic-acid inhibitor', 55.44595718383789),
#  ('8-hydroxyeicosatetraenoic-acid inhibitor', 55.44595718383789),
#  ('potassium-sparing', 53.406333923339844),
#  ('calcium antagonist', 53.03217172622681),
#  ('sodium-sparing', 50.38707256317139),
#  ('protein kinase C inhibitor', 50.38687586784363),
#  ('protein kinase D inhibitor', 50.38687586784363),
#  ('protein kinase inhibitor', 50.38687586784363),
#  ('protease inhibitor', 49.08213019371033),
#  ('estrogen receptor beta binder', 48.93285036087036),
#  ('nitric-oxide inhibitor', 48.89238774776459),
#  ('protein-tyrosine-kinase inhibitor', 48.55432212352753),
#  ('hydrogen-peroxide inhibitor', 47.78055250644684),
#  ('calcium channel blocker', 47.3043292760849),
#  ('hormone', 47.08269238471985),
#  ('mineral-corticoid', 46.808645129203796),
#  ('nitric-oxide-synthase inhibitor', 46.80411517620087),
#  ('activator-protein-1 inhibitor', 46.6132789850235)]
# 1050
# nutrients
# [('potassium-sparing', 55.94268441200256),
#  ('vitamin-A activity', 52.7692973613739),
#  ('sodium-sparing', 52.0516574382782),
#  ('digestive', 51.123279333114624),
#  ('calcium antagonist', 49.359700083732605),
#  ('toxic', 48.60750138759613),
#  ('nitric-oxide-genic', 48.24086129665375),
#  ('mineral-corticoid', 47.80844748020172),
#  ('hydrogen-peroxide inhibitor', 47.23955690860748),
#  ('calcium channel blocker', 46.51098549365997),
#  ('5-hydroxyeicosatetraenoic-acid inhibitor', 46.3395893573761),
#  ('8-hydroxyeicosatetraenoic-acid inhibitor', 46.3395893573761),
#  ('essential', 46.33876383304596),
#  ('nitric-oxide scavenger', 45.601606369018555),
#  ('anti C-reactive-protein', 45.15191614627838),
#  ('nitric-oxide inhibitor', 44.987866282463074),
#  ('choline-sparing', 44.97024118900299),
#  ('antioxidant', 43.904879689216614),
#  ('insulin-sparing', 43.584269285202026),
#  ('mitogen-activated-protein-kinase inhibitor', 43.063175678253174)]
# 1050
# minerals
# [('copper chelator', 64.11359906196594),
#  ('copper antagonist', 48.56516420841217),
#  ('toxic', 42.69481003284454),
#  ('metal chelator', 41.26313924789429),
#  ('vitamin-A activity', 39.95558023452759),
#  ('essential', 39.075592160224915),
#  ('calcium-sparing', 38.076549768447876),
#  ('nitric-oxide-genic', 37.851086258888245),
#  ('hydrogen-peroxide inhibitor', 35.860249400138855),
#  ('calcium antagonist', 35.249823331832886),
#  ('nitric-oxide inhibitor', 35.0784033536911),
#  ('nitric-oxide scavenger', 34.64736342430115),
#  ('anti alkali', 33.56099724769592),
#  ('aryl-hydrocarbon-hydroxylase inhibitor', 33.355653285980225),
#  ('pigment', 32.944321632385254),
#  ('advanced glycation end products inhibitor', 32.855841517448425),
#  ('nitric-oxide-synthase inhibitor', 32.788315415382385),
#  ('5-hydroxyeicosatetraenoic-acid inhibitor', 31.530770659446716),
#  ('8-hydroxyeicosatetraenoic-acid inhibitor', 31.530770659446716),
#  ('corrosive', 31.36352002620697)]
# 1050
# energetic
# [('anti neurotic', 45.398905873298645),
#  ('anti flatulent', 41.1248654127121),
#  ('anti anemic', 40.52497446537018),
#  ('anti manic', 40.13121724128723),
#  ('anti myopic', 39.95591104030609),
#  ('hypnotic', 39.79558050632477),
#  ('anti complementary', 39.374127984046936),
#  ('anti C-reactive-protein', 38.94692659378052),
#  ('anti hyperkinetic', 38.33085298538208),
#  ('anti complement', 37.657591700553894),
#  ('anti schizophrenic', 36.97980344295502),
#  ('anti autistic', 36.81725263595581),
#  ('anti dyspeptic', 36.45451068878174),
#  ('cathartic', 36.02980673313141),
#  ('anti apoplectic', 35.83267033100128),
#  ('central nervous system active', 35.631194710731506),
#  ('anti spasmodic', 35.071054100990295),
#  ('anti testosterone', 34.92199778556824),
#  ('anti shock', 34.55324470996857),
#  ('anti asthmatic', 34.54141616821289)]
# 1050
# energy
# [('anti advanced glycation end products', 52.70897150039673),
#  ('central nervous system active', 52.622777223587036),
#  ('mineral-corticoid', 52.41909623146057),
#  ('essential', 50.332945585250854),
#  ('central nervous system sedative', 48.432111740112305),
#  ('anti radiation', 47.29127585887909),
#  ('anti X-radiation', 47.29127585887909),
#  ('central nervous system inhibitor', 46.23767137527466),
#  ('central nervous system paralytic', 45.88586688041687),
#  ('advanced glycation end products inhibitor', 45.72388827800751),
#  ('central nervous system stimulant', 45.366331934928894),
#  ('anti glucose-tolerance-factor', 44.847172498703),
#  ('central nervous system depressant', 44.558992981910706),
#  ('vitamin-A activity', 43.76234710216522),
#  ('anti metabolic', 43.13865602016449),
#  ('nodulation signal', 42.86608695983887),
#  ('anti spare-tire', 42.50875413417816),
#  ('copper chelator', 42.35895276069641),
#  ('anti aging', 42.104506492614746),
#  ('anti hot-flash', 42.08964705467224)]

# %%
len(key_list)
# Out:
# 1050
